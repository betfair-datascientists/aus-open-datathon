# %%
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import sys
import warnings
warnings.filterwarnings('ignore')
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import sqlite3
import pandas_profiling
#from common_function import *

pd.options.display.max_columns = 999
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns
    

def reduce_mem_usage(df_):
    start_mem = df_.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for c in df_.columns[df_.dtypes != 'object']:
        col_type = df_[c].dtype
        
        c_min = df_[c].min()
        c_max = df_[c].max()
        if str(col_type)[:3] == 'int':
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                df_[c] = df_[c].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                df_[c] = df_[c].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                df_[c] = df_[c].astype(np.int32)
            else:
                df_[c] = df_[c].astype(np.int64)  
        else:
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                df_[c] = df_[c].astype(np.float16)
            elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                df_[c] = df_[c].astype(np.float32)
            else:
                df_[c] = df_[c].astype(np.float64)

    end_mem = df_.memory_usage().sum() / 1024**2
    print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df_

# %%
# Load the csv 
df_match_wide = pd.read_csv("data/ATP_matches.csv")

# Store the shape of the data for reference check later
original_shape = df_match_wide.shape

# %%
df_match_wide.columns
# Out:
# Index(['Winner', 'Loser', 'Tournament', 'Tournament_Date', 'Court_Surface',
#        'Round_Description', 'Winner_Rank', 'Loser_Rank', 'Retirement_Ind',
#        'Winner_Sets_Won', 'Winner_Games_Won', 'Winner_Aces',
#        'Winner_DoubleFaults', 'Winner_FirstServes_Won',
#        'Winner_FirstServes_In', 'Winner_SecondServes_Won',
#        'Winner_SecondServes_In', 'Winner_BreakPoints_Won',
#        'Winner_BreakPoints', 'Winner_ReturnPoints_Won',
#        'Winner_ReturnPoints_Faced', 'Winner_TotalPoints_Won', 'Loser_Sets_Won',
#        'Loser_Games_Won', 'Loser_Aces', 'Loser_DoubleFaults',
#        'Loser_FirstServes_Won', 'Loser_FirstServes_In',
#        'Loser_SecondServes_Won', 'Loser_SecondServes_In',
#        'Loser_BreakPoints_Won', 'Loser_BreakPoints', 'Loser_ReturnPoints_Won',
#        'Loser_ReturnPoints_Faced', 'Loser_TotalPoints_Won'],
#       dtype='object')

# %%
# What are the big tournaments in the data
#df_match_wide.Tournament.value_counts().head()

df_match_wide.groupby(['Tournament','Court_Surface']).size().reset_index().sort_values(0, ascending=False).head()
# Out:
#                     Tournament Court_Surface     0
# 8   Australian Open, Melbourne          Hard  1665
# 30          French Open, Paris          Clay  1664
# 82         U.S. Open, New York          Hard  1662
# 88           Wimbledon, London         Grass  1106
# 36                Indian Wells          Hard   653

# %%
numeric_columns = ['Winner_Rank', 'Loser_Rank', 'Retirement_Ind',
                   'Winner_Sets_Won', 'Winner_Games_Won', 'Winner_Aces',
                   'Winner_DoubleFaults', 'Winner_FirstServes_Won',
                   'Winner_FirstServes_In', 'Winner_SecondServes_Won',
                   'Winner_SecondServes_In', 'Winner_BreakPoints_Won',
                   'Winner_BreakPoints', 'Winner_ReturnPoints_Won',
                   'Winner_ReturnPoints_Faced', 'Winner_TotalPoints_Won', 'Loser_Sets_Won',
                   'Loser_Games_Won', 'Loser_Aces', 'Loser_DoubleFaults',
                   'Loser_FirstServes_Won', 'Loser_FirstServes_In',
                   'Loser_SecondServes_Won', 'Loser_SecondServes_In',
                   'Loser_BreakPoints_Won', 'Loser_BreakPoints', 'Loser_ReturnPoints_Won',
                   'Loser_ReturnPoints_Faced', 'Loser_TotalPoints_Won']

text_columns = ['Winner', 'Loser',  'Tournament', 'Court_Surface','Round_Description'] 

date_columns = ['Tournament_Date']

# %%
# '.' in ['Winner_Rank']

# %%
df_match_wide[numeric_columns] = df_match_wide[numeric_columns].apply(pd.to_numeric,errors = 'coerce')
df_match_wide[date_columns] = df_match_wide[date_columns].apply(pd.to_datetime)

# %%
missing_values_table(df_match_wide)
# Out:
# Your selected dataframe has 35 columns.
# There are 25 columns that have missing values.
#                            Missing Values  % of Total Values
# Winner_ReturnPoints_Won               376                1.8
# Winner_ReturnPoints_Faced             376                1.8
# Loser_ReturnPoints_Won                376                1.8
# Loser_ReturnPoints_Faced              376                1.8
# Loser_Rank                            297                1.4
# Winner_Rank                           100                0.5
# Winner_DoubleFaults                    38                0.2
# Loser_DoubleFaults                     35                0.2
# Round_Description                      34                0.2
# Loser_Aces                             17                0.1
# Loser_BreakPoints_Won                  15                0.1
# Winner_Aces                            15                0.1
# Loser_BreakPoints                      10                0.0
# Winner_Sets_Won                         8                0.0
# Loser_Sets_Won                          8                0.0
# Winner_BreakPoints                      7                0.0
# Winner_BreakPoints_Won                  7                0.0
# Winner_SecondServes_In                  2                0.0
# Winner_SecondServes_Won                 2                0.0
# Loser_SecondServes_Won                  2                0.0
# Loser_SecondServes_In                   2                0.0
# Loser_FirstServes_Won                   1                0.0
# Loser_FirstServes_In                    1                0.0
# Winner_FirstServes_In                   1                0.0
# Winner_FirstServes_Won                  1                0.0

# %%
df_match_wide.loc[df_match_wide.Winner_ReturnPoints_Won.isna()]
# Out:
#                       Winner                     Loser  \
# 1805             Marin Cilic               Sam Querrey
# 6158            Gilles Simon             Daniel Brands
# 8149              James Ward              Aldin Setkic
# 8160              Jimmy Wang              Daniel Evans
# 8161     Konstantin Kravchuk          Daniel Smethurst
# 8165             Sanam Singh            Flavio Cipolla
# 8170              Radu Albot         Gregoire Burquier
# 8171          Vincent Millot               Guido Pella
# 8180      Alex Bogomolov Jr.          Kimmer Coppejans
# 8198          Rhyne Williams   Roberto Carballes Baena
# 8202       Michal Przysiezny         Stefano Travaglia
# 8212           Yuichi Sugita  Adrian Menendez-Maceiras
# 8215            Emilio Gomez             Andrej Martin
# 8216                Ze Zhang           Austin Krajicek
# 8218         Peter Gojowczyk           Denys Molchanov
# 8219            Niels Desein              Gastao Elias
# 8220         Oscar Hernandez           Guido Andreozzi
# 8221              Jimmy Wang               Hyeon Chung
# 8223         Illya Marchenko                 Jan Mertl
# 8224    Juan Ignacio Londero         Jesse Huta Galung
# 8225       Michal Przysiezny       Konstantin Kravchuk
# 8226       Marco Chiudinelli              Malek Jaziri
# 8227        Filip Krajinovic          Marco Cecchinato
# 8228   Alexander Kudryavtsev              Martin Alund
# 8229              Radu Albot          Marton Fucsovics
# 8230      Matthias Bachinger              Matteo Viola
# 8231            Steve Darcis           Michael Russell
# 8232          Peter Polansky            Miloslav Mecir
# 8233            Aljaz Bedene      Nikoloz Basilashvili
# 8234                   Di Wu        Philipp Petzschner
# ...                      ...                       ...
# 11934         Dennis Novikov                James Ward
# 11944            Mirza Basic              Marius Copil
# 11948          Mischa Zverev            Norbert Gombos
# 11950       Bjorn Fratangelo        Oriol Roca Batalla
# 11951            James McGee                Radu Albot
# 11952            Tatsuma Ito           Tennys Sandgren
# 11955            Tatsuma Ito  Adrian Menendez-Maceiras
# 11957          Ryan Harrison      Aleksandr Nedovyesov
# 11960          Yuichi Sugita            Dennis Novikov
# 11961  Pierre-Hugues Herbert    Edouard Roger-Vasselin
# 11962          Daniel Brands               James McGee
# 11963        Stephane Robert           Karen Khachanov
# 11964            Tim Smyczek         Kenny De Schepper
# 11967          Jozef Kovalik           Ruben Bemelmans
# 11968            Mirza Basic             Saketh Myneni
# 11969            Renzo Olivo            Vincent Millot
# 11978         Simone Bolelli               Brian Baker
# 11987          Jeremy Chardy            Ernests Gulbis
# 11989            Denis Kudla          Filip Krajinovic
# 11994      Federico Delbonis              Ivo Karlovic
# 11997            Renzo Olivo               Jiri Vesely
# 11999      Marco Trungelliti             Jozef Kovalik
# 12002          Damir Dzumhur               Kyle Edmund
# 12005          Tommy Robredo              Malek Jaziri
# 12008  Roberto Bautista Agut             Martin Klizan
# 12020            Mirza Basic               Robin Haase
# 12024            Guido Pella              Steve Darcis
# 12059        Stephane Robert                Rajeev Ram
# 12096         Novak Djokovic             Roger Federer
# 19741         Kevin Anderson                John Isner
#
#                        Tournament Tournament_Date Court_Surface  \
# 1805            Wimbledon, London      2012-06-25         Grass
# 6158   Australian Open, Melbourne      2014-01-13          Hard
# 8149          U.S. Open, New York      2014-08-25          Hard
# 8160          U.S. Open, New York      2014-08-25          Hard
# 8161          U.S. Open, New York      2014-08-25          Hard
# 8165          U.S. Open, New York      2014-08-25          Hard
# 8170          U.S. Open, New York      2014-08-25          Hard
# 8171          U.S. Open, New York      2014-08-25          Hard
# 8180          U.S. Open, New York      2014-08-25          Hard
# 8198          U.S. Open, New York      2014-08-25          Hard
# 8202          U.S. Open, New York      2014-08-25          Hard
# 8212          U.S. Open, New York      2014-08-25          Hard
# 8215          U.S. Open, New York      2014-08-25          Hard
# 8216          U.S. Open, New York      2014-08-25          Hard
# 8218          U.S. Open, New York      2014-08-25          Hard
# 8219          U.S. Open, New York      2014-08-25          Hard
# 8220          U.S. Open, New York      2014-08-25          Hard
# 8221          U.S. Open, New York      2014-08-25          Hard
# 8223          U.S. Open, New York      2014-08-25          Hard
# 8224          U.S. Open, New York      2014-08-25          Hard
# 8225          U.S. Open, New York      2014-08-25          Hard
# 8226          U.S. Open, New York      2014-08-25          Hard
# 8227          U.S. Open, New York      2014-08-25          Hard
# 8228          U.S. Open, New York      2014-08-25          Hard
# 8229          U.S. Open, New York      2014-08-25          Hard
# 8230          U.S. Open, New York      2014-08-25          Hard
# 8231          U.S. Open, New York      2014-08-25          Hard
# 8216                       NaN                        NaN
# 8218                       NaN                        NaN
# 8219                       NaN                        NaN
# 8220                       NaN                        NaN
# 8221                       NaN                        NaN
# 8223                       NaN                        NaN
# 8224                       NaN                        NaN
# 8225                       NaN                        NaN
# 8226                       NaN                        NaN
# 8227                       NaN                        NaN
# 8228                       NaN                        NaN
# 8229                       NaN                        NaN
# 8230                       NaN                        NaN
# 8231                       NaN                        NaN
# 8232                       NaN                        NaN
# 8233                       NaN                        NaN
# 8234                       NaN                        NaN
# ...                        ...                        ...
# 11934                      NaN                        NaN
# 11944                      NaN                        NaN
# 11948                      NaN                        NaN
# 11950                      NaN                        NaN
# 11951                      NaN                        NaN
# 11952                      NaN                        NaN
# 11955                      NaN                        NaN
# 11957                      NaN                        NaN
# 11960                      NaN                        NaN
# 11961                      NaN                        NaN
# 11962                      NaN                        NaN
# 11963                      NaN                        NaN
# 11964                      NaN                        NaN
# 11967                      NaN                        NaN
# 11968                      NaN                        NaN
# 11969                      NaN                        NaN
# 11978                      NaN                        NaN
# 11987                      NaN                        NaN
# 11989                      NaN                        NaN
# 11994                      NaN                        NaN
# 11997                      NaN                        NaN
# 11999                      NaN                        NaN
# 12002                      NaN                        NaN
# 12005                      NaN                        NaN
# 12008                      NaN                        NaN
# 12020                      NaN                        NaN
# 12024                      NaN                        NaN
# 12059                      NaN                        NaN
# 12096                      NaN                        NaN
# 19741                      NaN                        NaN
#
#        Winner_TotalPoints_Won  Loser_Sets_Won  Loser_Games_Won  Loser_Aces  \
# 1805                      254             2.0               25        23.0
# 6158                      230             2.0               21        41.0
# 8149                       65             0.0                4         3.0
# 8160                      126             1.0               14         8.0
# 8161                       61             0.0                3         0.0
# 8165                       77             0.0                7         0.0
# 8170                       58             0.0                4         2.0
# 8171                       95             1.0               12         6.0
# 8180                       63             0.0                6         4.0
# 8198                       72             0.0                8         5.0
# 8202                      119             1.0               19         6.0
# 8212                       89             1.0               14         9.0
# 8215                      101             1.0               13        10.0
# 8216                      102             1.0               14         9.0
# 8218                       66             0.0                8         5.0
# 8219                       99             0.0               12         9.0
# 8220                       85             1.0               13         5.0
# 8221                       59             0.0                2         1.0
# 8223                       55             0.0                4         3.0
# 8224                       52             0.0                6         2.0
# 8225                       58             0.0                5         3.0
# 8226                      104             1.0               11        11.0
# 8227                       64             0.0                8         7.0
# 8228                       73             0.0                6         2.0
# 8229                       91             1.0               10         6.0
# 8230                       62             0.0                5         0.0
# 8231                       64             0.0                7         1.0
# 8232                       62             0.0                6         3.0
# 8233                       66             0.0                6         2.0
# 8234                       77             1.0               11         4.0
# ...                       ...             ...              ...         ...
# 11934                      78             0.0                9         4.0
# 11944                      67             0.0                9         6.0
# 11948                      56             0.0                3         1.0
# 11950                      84             1.0               11         2.0
# 11951                      72             1.0                9         1.0
# 11952                      69             0.0                6         0.0
# 11955                      74             1.0               14         9.0
# 11957                     124             1.0               16         7.0
# 11960                     101             1.0               13         8.0
# 11961                     104             1.0               16         4.0
# 11962                      71             0.0               10         2.0
# 11963                      75             1.0               12         5.0
# 8212                13.0                     NaN                       NaN
# 8215                 9.0                     NaN                       NaN
# 8216                 9.0                     NaN                       NaN
# 8218                 3.0                     NaN                       NaN
# 8219                11.0                     NaN                       NaN
# 8220                14.0                     NaN                       NaN
# 8221                 0.0                     NaN                       NaN
# 8223                 1.0                     NaN                       NaN
# 8224                 4.0                     NaN                       NaN
# 8225                 3.0                     NaN                       NaN
# 8226                 6.0                     NaN                       NaN
# 8227                 1.0                     NaN                       NaN
# 8228                 3.0                     NaN                       NaN
# 8229                13.0                     NaN                       NaN
# 8230                 4.0                     NaN                       NaN
# 8231                 3.0                     NaN                       NaN
# 8232                 2.0                     NaN                       NaN
# 8233                 4.0                     NaN                       NaN
# 8234                 6.0                     NaN                       NaN
# ...                  ...                     ...                       ...
# 11934                7.0                     NaN                       NaN
# 11944                4.0                     NaN                       NaN
# 11948                0.0                     NaN                       NaN
# 11950                5.0                     NaN                       NaN
# 11951                3.0                     NaN                       NaN
# 11952                3.0                     NaN                       NaN
# 11955                4.0                     NaN                       NaN
# 11957                9.0                     NaN                       NaN
# 11960               12.0                     NaN                       NaN
# 11961               12.0                     NaN                       NaN
# 11962                1.0                     NaN                       NaN
# 11963               10.0                     NaN                       NaN
# 11964               11.0                     NaN                       NaN
# 11967                4.0                     NaN                       NaN
# 11968               10.0                     NaN                       NaN
# 11969                7.0                     NaN                       NaN
# 11978                6.0                     NaN                       NaN
# 11987               17.0                     NaN                       NaN
# 11989                1.0                     NaN                       NaN
# 11994                3.0                     NaN                       NaN
# 11997               14.0                     NaN                       NaN
# 11999                4.0                     NaN                       NaN
# 12002               14.0                     NaN                       NaN
# 12005               14.0                     NaN                       NaN
# 12008               14.0                     NaN                       NaN
# 12020               12.0                     NaN                       NaN
# 12024               20.0                     NaN                       NaN
# 12059               20.0                     NaN                       NaN
# 12096                4.0                     NaN                       NaN
# 19741                5.0                     NaN                       NaN
#
#        Loser_TotalPoints_Won
# 1805                     245
# 6158                     231
# 8149                      40
# 8160                     112
# 8161                      31
# 8165                      54
# 8170                      37
# 8171                      85
# 8180                      47
# 8198                      54
# 8202                     122
# 8212                      88
# 8215                      95
# 8216                      89
# 8218                      53
# 8219                      89
# 8220                      88
# 8221                      29
# 8223                      38
# 8224                      45
# 8225                      41
# 8226                      89
# 8227                      55
# 8228                      56
# 8229                      82
# 8230                      48
# 8231                      47
# 8232                      43
# 8233                      50
# 8234                      72
# ...                      ...
# 11934                     67
# 11944                     52
# 11948                     30
# 11950                     75
# 11951                     63
# 11952                     50
# 11955                     76
# 11957                    117
# 11960                     86
# 11961                    100
# 11962                     62
# 11963                     78
# 11964                     96
# 11967                     68
# 11968                    104
# 11969                     59
# 11978                    156
# 11987                    212
# 11989                     34
# 11994                     69
# 11997                    158
# 11999                     95
# 12002                    152
# 12005                    214
# 12008                    143
# 12020                    106
# 12024                    141
# 12059                    178
# 12096                     82
# 19741                    271
#
# [376 rows x 35 columns]

# %%
# df_match_wide.Tournament_Date = pd.to_datetime(df_match_wide.Tournament_Date,dayfirst=True)

# %%
df_match_wide['Total_Games'] = df_match_wide.Winner_Games_Won + df_match_wide.Loser_Games_Won

# %%
winner_cols = [col for col in df_match_wide.columns if col.startswith('Winner')]
# winner_cols.append()

# 'Tournament', 'Court_Surface','Round_Description']

# date_columns = ['Tournament_Date']
loser_cols = [col for col in df_match_wide.columns if col.startswith('Loser')]

# %%
df_winner = df_match_wide[winner_cols + ['Tournament','Tournament_Date', 'Court_Surface','Round_Description','Total_Games']]
df_loser = df_match_wide[loser_cols + ['Tournament','Tournament_Date', 'Court_Surface','Round_Description','Total_Games']]


df_winner["won"] = 1
df_loser["won"] = 0


player_cols = [col.replace('Winner','Player') for col in winner_cols]

# Rename the columns so that they are the same for winners and losers
df_winner.columns = player_cols + ['Tournament','Tournament_Date', 'Court_Surface',
                                   'Round_Description','Total_Games',"won"]
df_loser.columns  = df_winner.columns

# %%
# append the winner and loser dfs together so now the dataframe is in long format

df_match_long = df_winner.append(df_loser)

del df_winner
del df_loser
gc.collect()
# Out:
# 0

# %%
def get_ratio_features(df):
    original_col = df.columns
    # Point Win ratio when serving
    df['F_Player_Serve_Win_Ratio'] = (df.Player_FirstServes_Won + df.Player_SecondServes_Won - df.Player_DoubleFaults) \
                                    /(df.Player_FirstServes_In + df.Player_SecondServes_In + df.Player_DoubleFaults)
    # Point win ratio when returning
    df['F_Player_Return_Win_Ratio'] = df.Player_ReturnPoints_Won / df.Player_ReturnPoints_Faced
    # Breakpoints per receiving game
    df['F_Player_BreakPoints_Per_Return_Game'] = df.Player_BreakPoints/df.Total_Games  
    df['F_Player_Game_Win_Percentage'] = df.Player_Games_Won/df.Total_Games

    ratio_columns = [col for col in df.columns if col not in original_col ]
    return df, ratio_columns

df_match_long,ratio_columns = get_ratio_features(df_match_long)

# %%
ratio_columns
# Out:
# ['F_Player_Serve_Win_Ratio',
#  'F_Player_Return_Win_Ratio',
#  'F_Player_BreakPoints_Per_Return_Game',
#  'F_Player_Game_Win_Percentage']

# %%
df_match_long.columns
# Out:
# Index(['Player', 'Player_Rank', 'Player_Sets_Won', 'Player_Games_Won',
#        'Player_Aces', 'Player_DoubleFaults', 'Player_FirstServes_Won',
#        'Player_FirstServes_In', 'Player_SecondServes_Won',
#        'Player_SecondServes_In', 'Player_BreakPoints_Won',
#        'Player_BreakPoints', 'Player_ReturnPoints_Won',
#        'Player_ReturnPoints_Faced', 'Player_TotalPoints_Won', 'Tournament',
#        'Tournament_Date', 'Court_Surface', 'Round_Description', 'Total_Games',
#        'won', 'F_Player_Serve_Win_Ratio', 'F_Player_Return_Win_Ratio',
#        'F_Player_BreakPoints_Per_Return_Game', 'F_Player_Game_Win_Percentage'],
#       dtype='object')

# %%
# The long table should have exactly twice of the rows of the original data
assert df_match_long.shape[0] == original_shape[0]*2

# %%
df_match_long.head()
# Out:
#                    Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 0  Edouard Roger-Vasselin        106.0              2.0                12
# 1               Dudi Sela         83.0              2.0                12
# 2                Go Soeda        120.0              2.0                19
# 3            Yuki Bhambri        345.0              2.0                12
# 4           Yuichi Sugita        235.0              2.0                12
#
#    Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 0          5.0                  2.0                    22.0
# 1          2.0                  0.0                    14.0
# 2          6.0                  1.0                    48.0
# 3          1.0                  2.0                    22.0
# 4          3.0                  1.0                    37.0
#
#    Player_FirstServes_In  Player_SecondServes_Won  Player_SecondServes_In  \
# 0                   30.0                     12.0                    19.0
# 1                   17.0                     11.0                    16.0
# 2                   64.0                     19.0                    39.0
# 3                   29.0                      9.0                    17.0
# 4                   51.0                     11.0                    27.0
#
#    Player_BreakPoints_Won  Player_BreakPoints  Player_ReturnPoints_Won  \
# 0                     4.0                 7.0                     25.0
# 1                     6.0                14.0                     36.0
# 2                     5.0                11.0                     42.0
# 3                     5.0                13.0                     34.0
# 4                     3.0                 7.0                     22.0
#
#    Player_ReturnPoints_Faced  Player_TotalPoints_Won Tournament  \
# 0                       59.0                      59    Chennai
# 1                       58.0                      61    Chennai
# 2                      105.0                     109    Chennai
# 3                       62.0                      65    Chennai
# 4                       54.0                      70    Chennai
#
#   Tournament_Date Court_Surface Round_Description  Total_Games  won  \
# 0      2012-01-02          Hard       First Round           19    1
# 1      2012-01-02          Hard       First Round           13    1
# 2      2012-01-02          Hard       First Round           33    1
# 3      2012-01-02          Hard       First Round           17    1
# 4      2012-01-02          Hard       First Round           19    1
#
#    F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 0                  0.627451                   0.423729
# 1                  0.757576                   0.620690
# 2                  0.634615                   0.400000
# 3                  0.604167                   0.548387
# 4                  0.594937                   0.407407
#
#    F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage
# 0                              0.368421                      0.631579
# 1                              1.076923                      0.923077
# 2                              0.333333                      0.575758
# 3                              0.764706                      0.705882
# 4                              0.368421                      0.631579

# %%
# tournaments that are similar to aus open which is french open and aus mel
tournament_train = ['French Open, Paris','Australian Open, Melbourne']

# %%
df_match_wide.loc[df_match_wide.Tournament.isin(tournament_train)].groupby(['Tournament','Tournament_Date']) \
.size().reset_index().sort_values(['Tournament','Tournament_Date'])

# check if there is more than one tournament date for each tournament per year
# Out:
#                     Tournament Tournament_Date    0
# 0   Australian Open, Melbourne      2012-01-16  237
# 1   Australian Open, Melbourne      2013-01-14  239
# 2   Australian Open, Melbourne      2014-01-13  238
# 3   Australian Open, Melbourne      2015-01-19  238
# 4   Australian Open, Melbourne      2016-01-18  239
# 5   Australian Open, Melbourne      2017-01-16  239
# 6   Australian Open, Melbourne      2018-01-15  235
# 7           French Open, Paris      2012-05-28  239
# 8           French Open, Paris      2013-05-27  238
# 9           French Open, Paris      2014-05-26  238
# 10          French Open, Paris      2015-05-25  236
# 11          French Open, Paris      2016-05-23  237
# 12          French Open, Paris      2017-05-29  238
# 13          French Open, Paris      2018-05-28  238

# %%
tournament_date_train = df_match_wide.loc[df_match_wide.Tournament.isin(tournament_train)].groupby(['Tournament','Tournament_Date']) \
.size().reset_index()[['Tournament','Tournament_Date']]

# %%
tournament_date_train.head()
# Out:
#                    Tournament Tournament_Date
# 0  Australian Open, Melbourne      2012-01-16
# 1  Australian Open, Melbourne      2013-01-14
# 2  Australian Open, Melbourne      2014-01-13
# 3  Australian Open, Melbourne      2015-01-19
# 4  Australian Open, Melbourne      2016-01-18

# %%
# # some cells have . but we will convert them into null

# # stats_cols = ['Rank', 'Retirement_Ind', 'Sets_Won', 'Games_Won',
# #        'Aces', 'DoubleFaults', 'FirstServes_Won', 'FirstServes_In',
# #        'SecondServes_Won', 'SecondServes_In', 'BreakPoints_Won', 'BreakPoints',
# #        'ReturnPoints_Won', 'ReturnPoints_Faced', 'TotalPoints_Won', 'won',]



# df_match_long = df_match_long.sort_values(['Player','Tournament_Date','Tournament'], ascending=True)

# %%
# df_player = get_feature_period(df_player)

# %%
#df_match_long['Total_Games'] = df_match_long.FirstServes_Won

# %%
df_match_long.columns
# Out:
# Index(['Player', 'Player_Rank', 'Player_Sets_Won', 'Player_Games_Won',
#        'Player_Aces', 'Player_DoubleFaults', 'Player_FirstServes_Won',
#        'Player_FirstServes_In', 'Player_SecondServes_Won',
#        'Player_SecondServes_In', 'Player_BreakPoints_Won',
#        'Player_BreakPoints', 'Player_ReturnPoints_Won',
#        'Player_ReturnPoints_Faced', 'Player_TotalPoints_Won', 'Tournament',
#        'Tournament_Date', 'Court_Surface', 'Round_Description', 'Total_Games',
#        'won', 'F_Player_Serve_Win_Ratio', 'F_Player_Return_Win_Ratio',
#        'F_Player_BreakPoints_Per_Return_Game', 'F_Player_Game_Win_Percentage'],
#       dtype='object')

# %%
def get_rolling_features (df, date_df=None,rolling_cols = None ):
    
    # Need to sort the data first so its from old to recent
    df = df.sort_values(['Player','Tournament_Date','Tournament'], ascending=True)
    
    # For each year, get the rolling averages of that player's past matches before the tournament start date
    for index, tournament_date in enumerate(date_df.Tournament_Date):
    
        # create a temp df to store the intrim results
        df_temp = df.loc[df.Tournament_Date < tournament_date]

        # take the most recent 20 matches for the rolling average
        df_temp = df_temp.groupby('Player')[rolling_cols].rolling(500, min_periods=1).mean().reset_index()
        df_temp = df_temp.groupby('Player').tail(1)

        if index ==0:
            # create the result dataframe
            df_result = df_temp
            # so we know which tournament this feature is for
            df_result['tournament_date_index'] = tournament_date
        else:
            df_temp['tournament_date_index'] = tournament_date
            df_result = df_result.append(df_temp)
    df_result.drop('level_1', axis=1,inplace=True)
    
    return df_result

# %%
# columns we are taking rolling averages from
rolling_cols = ['Player_Rank', 'Player_Sets_Won', 'Player_Games_Won',
           'Player_Aces', 'Player_DoubleFaults', 'Player_FirstServes_Won',
           'Player_FirstServes_In', 'Player_SecondServes_Won',
           'Player_SecondServes_In', 'Player_BreakPoints_Won',
           'Player_BreakPoints', 'Player_ReturnPoints_Won',
           'Player_ReturnPoints_Faced', 'Player_TotalPoints_Won', 'Total_Games',
           'won', 'F_Player_Serve_Win_Ratio', 'F_Player_Return_Win_Ratio',
           'F_Player_BreakPoints_Per_Return_Game', 'F_Player_Game_Win_Percentage']

    
df_result_long = get_rolling_features (df_match_long, tournament_date_train,rolling_cols )

# %%
df_match_long.shape
# Out:
# (41614, 25)

# %%
df_match_long.head(20)
# 5                               0.533333                      0.800000
# 6                               0.210526                      0.631579
# 7                               0.333333                      0.666667
# 8                               0.272727                      0.590909
# 9                               0.100000                      0.566667
# 10                              0.444444                      0.592593
# 11                              0.571429                      0.571429
# 12                              0.250000                      0.571429
# 13                              0.366667                      0.533333
# 14                              0.318182                      0.590909
# 15                              0.352941                      0.705882
# 16                              0.434783                      0.565217
# 17                              0.250000                      0.750000
# 18                              0.520000                      0.600000
# 19                              0.045455                      0.590909

# %%
example_true = df_match_long.loc[df_match_long.Player == 'Adam Pavlasek']

# %%
example_calculated = df_result_long.loc[df_result_long.Player == 'Adam Pavlasek']

# %%
example_true
# Out:
#               Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 8917   Adam Pavlasek        240.0              2.0                13
# 13080  Adam Pavlasek        132.0              2.0                15
# 13131  Adam Pavlasek        132.0              2.0                12
# 13214  Adam Pavlasek        132.0              3.0                23
# 13717  Adam Pavlasek        116.0              2.0                12
# 13725  Adam Pavlasek        116.0              2.0                12
# 16571  Adam Pavlasek        136.0              3.0                24
# 19109  Adam Pavlasek        185.0              1.0                 6
# 19176  Adam Pavlasek        185.0              2.0                12
# 19198  Adam Pavlasek        185.0              2.0                13
# 19249  Adam Pavlasek        185.0              3.0                25
# 19524  Adam Pavlasek        145.0              2.0                12
# 8978   Adam Pavlasek        240.0              1.0                11
# 11062  Adam Pavlasek        149.0              0.0                 7
# 13149  Adam Pavlasek        132.0              1.0                10
# 13229  Adam Pavlasek        132.0              0.0                10
# 13729  Adam Pavlasek        116.0              1.0                16
# 14549  Adam Pavlasek         89.0              0.0                 8
# 14966  Adam Pavlasek         86.0              1.0                15
# 15400  Adam Pavlasek         93.0              0.0                 4
# 15524  Adam Pavlasek         96.0              0.0                 5
# 15643  Adam Pavlasek         98.0              1.0                10
# 16038  Adam Pavlasek         97.0              1.0                13
# 16618  Adam Pavlasek        136.0              0.0                 5
# 17904  Adam Pavlasek        208.0              1.0                15
# 19276  Adam Pavlasek        185.0              0.0                 5
# 19570  Adam Pavlasek        145.0              1.0                10
# 20164  Adam Pavlasek        210.0              1.0                10
#
#        Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 8917           5.0                  1.0                    28.0
# 13080          9.0                  3.0                    42.0
# 13131          3.0                  0.0                    23.0
# 13214          7.0                  2.0                    66.0
# 13717          3.0                  4.0                    25.0
# 13725          6.0                  2.0                    24.0
# 16571         14.0                  5.0                    59.0
# 19109          0.0                  1.0                     9.0
# 19176          5.0                  0.0                    25.0
# 19198          7.0                  2.0                    42.0
# 19249         16.0                  3.0                    66.0
# 19524          6.0                  1.0                    32.0
# 8978          18.0                 10.0                    66.0
# 11062          2.0                  1.0                    17.0
# 13149          2.0                  2.0                    33.0
# 13229          5.0                  4.0                    42.0
# 13729          9.0                  5.0                    45.0
# 14549          6.0                  3.0                    29.0
# 14966         13.0                  3.0                    47.0
# 15400          5.0                  3.0                    19.0
# 15524          3.0                  3.0                    17.0
# 15643          5.0                  5.0                    29.0
# 16038          5.0                  4.0                    27.0
# 16618          5.0                  4.0                    26.0
# 13214                   0.451852                              0.414634
# 13717                   0.416667                              0.315789
# 13725                   0.466667                              0.277778
# 16571                   0.433071                              0.500000
# 19109                   0.692308                              0.555556
# 19176                   0.553571                              0.812500
# 19198                   0.382716                              0.347826
# 19249                   0.387597                              0.243902
# 19524                   0.363636                              0.157895
# 8978                         NaN                              0.185185
# 11062                        NaN                              0.050000
# 13149                   0.366197                              0.160000
# 13229                   0.164179                              0.000000
# 13729                   0.303030                              0.058824
# 14549                   0.333333                              0.285714
# 14966                   0.330357                              0.189189
# 15400                   0.340000                              0.125000
# 15524                   0.333333                              0.117647
# 15643                   0.323529                              0.074074
# 16038                   0.412371                              0.518519
# 16618                   0.216667                              0.043478
# 17904                   0.218391                              0.129032
# 19276                   0.238806                              0.043478
# 19570                   0.333333                              0.333333
# 20164                   0.350649                              0.291667
#
#        F_Player_Game_Win_Percentage
# 8917                       0.650000
# 13080                      0.535714
# 13131                      0.750000
# 13214                      0.560976
# 13717                      0.631579
# 13725                      0.666667
# 16571                      0.666667
# 19109                      0.666667
# 19176                      0.750000
# 19198                      0.565217
# 19249                      0.609756
# 19524                      0.631579
# 8978                       0.407407
# 11062                      0.350000
# 13149                      0.400000
# 13229                      0.357143
# 13729                      0.470588
# 14549                      0.380952
# 14966                      0.405405
# 15400                      0.250000
# 15524                      0.294118
# 15643                      0.370370
# 16038                      0.481481
# 16618                      0.217391
# 17904                      0.483871
# 19276                      0.217391
# 19570                      0.476190
# 20164                      0.416667

# %%
example_calculated
# Out:
#            Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 4   Adam Pavlasek   209.666667         1.000000         10.333333
# 13  Adam Pavlasek   143.833333         1.333333         12.416667
# 20  Adam Pavlasek   129.894737         1.157895         11.842105
# 3   Adam Pavlasek   240.000000         1.500000         12.000000
# 4   Adam Pavlasek   209.666667         1.000000         10.333333
# 17  Adam Pavlasek   131.187500         1.125000         11.437500
# 21  Adam Pavlasek   133.800000         1.150000         12.000000
#
#     Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 4      8.333333             4.000000               37.000000
# 13     6.250000             3.083333               36.666667
# 20     6.578947             3.368421               34.947368
# 3     11.500000             5.500000               47.000000
# 4      8.333333             4.000000               37.000000
# 17     6.312500             3.187500               34.500000
# 21     6.850000             3.250000               35.400000
#
#     Player_FirstServes_In  Player_SecondServes_Won  Player_SecondServes_In  \
# 4               54.333333                23.333333               44.333333
# 13              52.833333                17.833333               35.416667
# 20              50.842105                16.736842               35.210526
# 3               66.000000                26.500000               51.500000
# 4               54.333333                23.333333               44.333333
# 17              50.687500                16.562500               34.875000
# 21              51.650000                16.700000               35.100000
#
#     Player_BreakPoints_Won  Player_BreakPoints  Player_ReturnPoints_Won  \
# 4                 2.000000            4.333333                      NaN
# 13                2.833333            5.833333                29.000000
# 20                2.789474            6.105263                28.750000
# 3                 2.500000            6.000000                      NaN
# 4                 2.000000            4.333333                      NaN
# 17                2.562500            5.187500                27.076923
# 21                2.800000            6.000000                28.176471
#
#     Player_ReturnPoints_Faced  Player_TotalPoints_Won  Total_Games       won  \
# 4                         NaN               90.000000    22.333333  0.333333
# 13                  76.000000               83.666667    24.750000  0.500000
# 20                  77.687500               80.578947    25.263158  0.368421
# 3                         NaN              109.000000    23.500000  0.500000
# 4                         NaN               90.000000    22.333333  0.333333
# 17                  73.769231               78.625000    24.625000  0.375000
# 21                  78.235294               81.000000    25.550000  0.350000
#
#     F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 4                   0.570862                        NaN
# 13                  0.580659                   0.382870
# 20                  0.544621                   0.364698
# 3                   0.590164                        NaN
# 4                   0.570862                        NaN
# 17                  0.546238                   0.367158
# 21                  0.546598                   0.356091
#
#     F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage  \
# 4                               0.195062                      0.469136
# 13                              0.238815                      0.513419
# 20                              0.233352                      0.465603
# 3                               0.267593                      0.528704
# 4                               0.195062                      0.469136
# 17                              0.210731                      0.467557
# 21                              0.228136                      0.466517
#
#    tournament_date_index
# 4             2016-01-18
# 13            2017-01-16
# 20            2018-01-15
# 3             2015-05-25
# 4             2016-05-23
# 17            2017-05-29
# 21            2018-05-28

# %%
example_true.loc[example_true.Tournament_Date<'2018-01-15','Player_Rank'].mean()
# Out:
# 129.89473684210526

# %%
example_true.shape
# Out:
# (28, 25)

# %%
example_true.loc[example_true.Tournament_Date<'2016-01-18','Player_Rank'].mean()
# Out:
# 209.66666666666666

# %%
df_result_long.tail()
# Out:
#                  Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 38152  Yusuke Takahashi   262.000000              1.0         14.000000
# 38155   Zbynek Mlynarik   227.333333              1.0         10.666667
# 38190          Ze Zhang   202.085714              0.8          9.885714
# 38196            Zhe Li   258.666667              0.5          6.666667
# 38201     Zhizhen Zhang   530.200000              1.4         11.600000
#
#        Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 38152     4.000000             2.000000               28.000000
# 38155     5.666667             6.333333               29.000000
# 38190     3.485714             4.200000               29.942857
# 38196     2.500000             0.833333               23.000000
# 38201     5.800000             2.600000               30.600000
#
#        Player_FirstServes_In  Player_SecondServes_Won  Player_SecondServes_In  \
# 38152              43.000000                22.000000               44.000000
# 38155              38.666667                17.333333               41.666667
# 38190              46.942857                11.771429               26.228571
# 38196              37.500000                 9.166667               21.333333
# 38201              42.800000                15.800000               32.800000
#
#        Player_BreakPoints_Won  Player_BreakPoints  Player_ReturnPoints_Won  \
# 38152                4.000000           10.000000                 36.00000
# 38155                2.000000            5.666667                 23.00000
# 38190                2.371429            5.885714                 24.71875
# 38196                1.166667            3.666667                 17.50000
# 38201                2.400000            6.000000                 26.60000
#
#        Player_ReturnPoints_Faced  Player_TotalPoints_Won  Total_Games  \
# 38152                  90.000000               86.000000    30.000000
# 38155                  74.000000               71.333333    23.666667
# 38190                  69.343750               67.685714    22.800000
# 38196                  54.833333               49.666667    18.500000
# 38201                  71.600000               73.000000    22.600000
#
#             won  F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 38152  0.000000                  0.539326                   0.400000
# 38155  0.333333                  0.455619                   0.309642
# 38190  0.285714                  0.477999                   0.345740
# 38196  0.166667                  0.503743                   0.302598
# 38201  0.600000                  0.552725                   0.366874
#
#        F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage  \
# 38152                              0.333333                      0.466667
# 38155                              0.239130                      0.447930
# 38190                              0.250178                      0.418596
# 38196                              0.173115                      0.329774
# 38201                              0.291449                      0.515139
#
#       tournament_date_index
# 38152            2018-05-28
# 38155            2018-05-28
# 38190            2018-05-28
# 38196            2018-05-28
# 38201            2018-05-28

# %%
# Randomise the match_wide dataset so the first player is not always the winner

# set a seed so the random number is reproducable
np.random.seed(2)

# randomise a number 0/1 with 50% chance each
# if 0 then take the winner, 1 then take loser

df_match_wide['random_number'] = np.random.randint(2, size=len(df_match_wide))

df_match_wide['randomised_player_1'] = np.where(df_match_wide['random_number']==0,df_match_wide['Winner'],df_match_wide['Loser'])
df_match_wide['randomised_player_2'] = np.where(df_match_wide['random_number']==0,df_match_wide['Loser'],df_match_wide['Winner'])

# set the target (win/loss) based on the new randomise number

df_match_wide['player_1_win'] = np.where(df_match_wide['random_number']==0,1,0)

# %%
df_match_wide.tail()
# Out:
#                         Winner                    Loser Tournament  \
# 20802          Karen Khachanov           Novak Djokovic      Paris
# 20803  Jaume Antoni Munar Clar           Frances Tiafoe      Milan
# 20804           Frances Tiafoe           Hubert Hurkacz      Milan
# 20805           Hubert Hurkacz  Jaume Antoni Munar Clar      Milan
# 20806            Andrey Rublev             Liam Caruana      Milan
#
#       Tournament_Date Court_Surface Round_Description  Winner_Rank  \
# 20802      2018-10-29   Indoor Hard            Finals         18.0
# 20803      2018-11-05   Indoor Hard               NaN         76.0
# 20804      2018-11-05   Indoor Hard               NaN         40.0
# 20805      2018-11-05   Indoor Hard               NaN         85.0
# 20806      2018-11-05   Indoor Hard               NaN         68.0
#
#        Loser_Rank  Retirement_Ind  Winner_Sets_Won  Winner_Games_Won  \
# 20802         2.0               0              2.0                13
# 20803        40.0               0              3.0                12
# 20804        85.0               0              3.0                14
# 20805        76.0               0              3.0                17
# 20806         NaN               0              3.0                12
#
#        Winner_Aces  Winner_DoubleFaults  Winner_FirstServes_Won  \
# 20802          9.0                  2.0                    38.0
# 20803          7.0                  1.0                    25.0
# 20804         11.0                  1.0                    39.0
# 20805          5.0                  3.0                    38.0
# 20806          9.0                  2.0                    33.0
#
#        Winner_FirstServes_In  Winner_SecondServes_Won  Winner_SecondServes_In  \
# 20802                   50.0                      8.0                    16.0
# 20803                   27.0                     16.0                    19.0
# 20804                   53.0                     17.0                    25.0
# 20805                   53.0                     13.0                    27.0
# 20806                   39.0                      6.0                    18.0
#
#        Winner_BreakPoints_Won  Winner_BreakPoints  Winner_ReturnPoints_Won  \
# 20802                     3.0                 8.0                     27.0
# 20803                     2.0                 4.0                     19.0
# 20804                     2.0                 7.0                     22.0
# 20805                     6.0                12.0                     40.0
# 20806                     3.0                 5.0                     21.0
#
#        Winner_ReturnPoints_Faced  Winner_TotalPoints_Won  Loser_Sets_Won  \
# 20802                       71.0                      73             0.0
# 20803                       46.0                      60             0.0
# 20804                       67.0                      78             1.0
# 20805                       98.0                      91             2.0
# 20806                       53.0                      60             0.0
#
#        Loser_Games_Won  Loser_Aces  Loser_DoubleFaults  Loser_FirstServes_Won  \
# 20802                9         5.0                 1.0                   30.0
# 20803                5         6.0                 3.0                   21.0
# 20804               10         9.0                 4.0                   35.0
# 20805               13         8.0                 1.0                   43.0
# 20806                6         6.0                 1.0                   28.0
#
#        Loser_FirstServes_In  Loser_SecondServes_Won  Loser_SecondServes_In  \
# 20802                  43.0                    14.0                   28.0
# 20803                  29.0                     6.0                   17.0
# 20804                  48.0                    10.0                   19.0
# 20805                  63.0                    15.0                   35.0
# 20806                  39.0                     4.0                   14.0
#
#        Loser_BreakPoints_Won  Loser_BreakPoints  Loser_ReturnPoints_Won  \
# 20802                    1.0                5.0                    20.0
# 20803                    0.0                2.0                     5.0
# 20804                    1.0                7.0                    22.0
# 20805                    3.0                9.0                    29.0
# 20806                    1.0                3.0                    18.0
#
#        Loser_ReturnPoints_Faced  Loser_TotalPoints_Won  Total_Games  \
# 20802                      66.0                     64           22
# 20803                      46.0                     32           17
# 20804                      78.0                     67           24
# 20805                      80.0                     87           30
# 20806                      57.0                     50           18
#
#        random_number      randomised_player_1      randomised_player_2  \
# 20802              0          Karen Khachanov           Novak Djokovic
# 20803              0  Jaume Antoni Munar Clar           Frances Tiafoe
# 20804              1           Hubert Hurkacz           Frances Tiafoe
# 20805              0           Hubert Hurkacz  Jaume Antoni Munar Clar
# 20806              1             Liam Caruana            Andrey Rublev
#
#        player_1_win
# 20802             1
# 20803             1
# 20804             0
# 20805             1
# 20806             0

# %%
df_match_wide['random_number'].mean()
# Out:
# 0.5032441005430864

# %%
df_match_wide['player_1_win'].mean()
# Out:
# 0.49675589945691356

# %%
df_match_wide.head()
# Out:
#                    Winner           Loser Tournament Tournament_Date  \
# 0  Edouard Roger-Vasselin     Eric Prodon    Chennai      2012-01-02
# 1               Dudi Sela   Fabio Fognini    Chennai      2012-01-02
# 2                Go Soeda   Frederico Gil    Chennai      2012-01-02
# 3            Yuki Bhambri      Karol Beck    Chennai      2012-01-02
# 4           Yuichi Sugita  Olivier Rochus    Chennai      2012-01-02
#
#   Court_Surface Round_Description  Winner_Rank  Loser_Rank  Retirement_Ind  \
# 0          Hard       First Round        106.0        97.0               0
# 1          Hard       First Round         83.0        48.0               0
# 2          Hard       First Round        120.0       102.0               0
# 3          Hard       First Round        345.0       101.0               0
# 4          Hard       First Round        235.0        67.0               0
#
#    Winner_Sets_Won  Winner_Games_Won  Winner_Aces  Winner_DoubleFaults  \
# 0              2.0                12          5.0                  2.0
# 1              2.0                12          2.0                  0.0
# 2              2.0                19          6.0                  1.0
# 3              2.0                12          1.0                  2.0
# 4              2.0                12          3.0                  1.0
#
#    Winner_FirstServes_Won  Winner_FirstServes_In  Winner_SecondServes_Won  \
# 0                    22.0                   30.0                     12.0
# 1                    14.0                   17.0                     11.0
# 2                    48.0                   64.0                     19.0
# 3                    22.0                   29.0                      9.0
# 4                    37.0                   51.0                     11.0
#
#    Winner_SecondServes_In  Winner_BreakPoints_Won  Winner_BreakPoints  \
# 0                    19.0                     4.0                 7.0
# 1                    16.0                     6.0                14.0
# 2                    39.0                     5.0                11.0
# 3                    17.0                     5.0                13.0
# 4                    27.0                     3.0                 7.0
#
#    Winner_ReturnPoints_Won  Winner_ReturnPoints_Faced  Winner_TotalPoints_Won  \
# 0                     25.0                       59.0                      59
# 1                     36.0                       58.0                      61
# 2                     42.0                      105.0                     109
# 3                     34.0                       62.0                      65
# 4                     22.0                       54.0                      70
#
#    Loser_Sets_Won  Loser_Games_Won  Loser_Aces  Loser_DoubleFaults  \
# 0             0.0                7         2.0                 3.0
# 1             0.0                1         1.0                 4.0
# 2             1.0               14         5.0                 2.0
# 3             0.0                5         1.0                 1.0
# 4             0.0                7         0.0                 0.0
#
#    Loser_FirstServes_Won  Loser_FirstServes_In  Loser_SecondServes_Won  \
# 0                   21.0                  33.0                    13.0
# 1                   17.0                  32.0                     5.0
# 2                   45.0                  70.0                    18.0
# 3                   15.0                  33.0                    13.0
# 4                   19.0                  32.0                    13.0
#
#    Loser_SecondServes_In  Loser_BreakPoints_Won  Loser_BreakPoints  \
# 0                   26.0                    1.0                3.0
# 1                   26.0                    0.0                1.0
# 2                   35.0                    2.0                4.0
# 3                   29.0                    2.0                3.0
# 4                   22.0                    1.0                7.0
#
#    Loser_ReturnPoints_Won  Loser_ReturnPoints_Faced  Loser_TotalPoints_Won  \
# 0                    15.0                      49.0                     49
# 1                     8.0                      33.0                     30
# 2                    36.0                     103.0                     99
# 3                    15.0                      46.0                     43
# 4                    30.0                      78.0                     62
#
#    Total_Games  random_number     randomised_player_1 randomised_player_2  \
# 0           19              0  Edouard Roger-Vasselin         Eric Prodon
# 1           13              1           Fabio Fognini           Dudi Sela
# 2           33              1           Frederico Gil            Go Soeda
# 3           17              0            Yuki Bhambri          Karol Beck
# 4           19              0           Yuichi Sugita      Olivier Rochus
#
#    player_1_win
# 0             1
# 1             0
# 2             0
# 3             1
# 4             1

# %%
df_match_wide_train = df_match_wide.loc[df_match_wide.Tournament.isin(tournament_train), \
                                           ['Winner','Loser','Tournament','Tournament_Date',
                                           'player_1_win','randomised_player_1','randomised_player_2','random_number']]

# Get the rolling features

df_match_wide_train = df_match_wide_train.merge(df_result_long, how='left',
                         left_on = ['randomised_player_1','Tournament_Date'],
                         right_on = ['Player','tournament_date_index'],validate ='m:1')

df_match_wide_train = df_match_wide_train.merge(df_result_long, how='left',
                         left_on = ['randomised_player_2','Tournament_Date'],
                         right_on = ['Player','tournament_date_index'],validate ='m:1',suffixes=('_p1','_p2'))

# %%
df_match_wide_train.head()
# Out:
#                      Winner               Loser                  Tournament  \
# 0  Adrian Menendez-Maceiras  Alejandro Gonzalez  Australian Open, Melbourne
# 1            Marco Crugnola      Amir Weintraub  Australian Open, Melbourne
# 2              Sergei Bubka      Andre Begemann  Australian Open, Melbourne
# 3           Denys Molchanov       Andrew Harris  Australian Open, Melbourne
# 4                Bjorn Phau      Arnaud Clement  Australian Open, Melbourne
#
#   Tournament_Date  player_1_win       randomised_player_1 randomised_player_2  \
# 0      2012-01-16             1  Adrian Menendez-Maceiras  Alejandro Gonzalez
# 1      2012-01-16             1            Marco Crugnola      Amir Weintraub
# 2      2012-01-16             0            Andre Begemann        Sergei Bubka
# 3      2012-01-16             0             Andrew Harris     Denys Molchanov
# 4      2012-01-16             0            Arnaud Clement          Bjorn Phau
#
#    random_number Player_p1  Player_Rank_p1  Player_Sets_Won_p1  \
# 0              0       NaN             NaN                 NaN
# 1              0       NaN             NaN                 NaN
# 2              1       NaN             NaN                 NaN
# 3              1       NaN             NaN                 NaN
# 4              1       NaN             NaN                 NaN
#
#    Player_Games_Won_p1  Player_Aces_p1  Player_DoubleFaults_p1  \
# 0                  NaN             NaN                     NaN
# 1                  NaN             NaN                     NaN
# 2                  NaN             NaN                     NaN
# 3                  NaN             NaN                     NaN
# 4                  NaN             NaN                     NaN
#
#    Player_FirstServes_Won_p1  Player_FirstServes_In_p1  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    Player_SecondServes_Won_p1  Player_SecondServes_In_p1  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Player_BreakPoints_Won_p1  Player_BreakPoints_p1  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    Player_ReturnPoints_Won_p1  Player_ReturnPoints_Faced_p1  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    Player_TotalPoints_Won_p1  Total_Games_p1  won_p1  \
# 0                        NaN             NaN     NaN
# 1                        NaN             NaN     NaN
# 2                        NaN             NaN     NaN
# 3                        NaN             NaN     NaN
# 4                        NaN             NaN     NaN
#
#    F_Player_Serve_Win_Ratio_p1  F_Player_Return_Win_Ratio_p1  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    F_Player_BreakPoints_Per_Return_Game_p1  F_Player_Game_Win_Percentage_p1  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   tournament_date_index_p1     Player_p2  Player_Rank_p2  Player_Sets_Won_p2  \
# 0                      NaT           NaN             NaN                 NaN
# 1                      NaT           NaN             NaN                 NaN
# 2                      NaT  Sergei Bubka           148.0                 1.0
# 3                      NaT           NaN             NaN                 NaN
# 4                      NaT           NaN             NaN                 NaN
#
#    Player_Games_Won_p2  Player_Aces_p2  Player_DoubleFaults_p2  \
# 0                  NaN             NaN                     NaN
# 1                  NaN             NaN                     NaN
# 2                  8.0             5.0                     4.0
# 3                  NaN             NaN                     NaN
# 4                  NaN             NaN                     NaN
#
#    Player_FirstServes_Won_p2  Player_FirstServes_In_p2  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                       26.0                      46.0
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    Player_SecondServes_Won_p2  Player_SecondServes_In_p2  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                        11.0                       26.0
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Player_BreakPoints_Won_p2  Player_BreakPoints_p2  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        2.0                    8.0
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    Player_ReturnPoints_Won_p2  Player_ReturnPoints_Faced_p2  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                        25.0                          73.0
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    Player_TotalPoints_Won_p2  Total_Games_p2  won_p2  \
# 0                        NaN             NaN     NaN
# 1                        NaN             NaN     NaN
# 2                       62.0            24.0     0.0
# 3                        NaN             NaN     NaN
# 4                        NaN             NaN     NaN
#
#    F_Player_Serve_Win_Ratio_p2  F_Player_Return_Win_Ratio_p2  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                     0.434211                      0.342466
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    F_Player_BreakPoints_Per_Return_Game_p2  F_Player_Game_Win_Percentage_p2  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                 0.333333                         0.333333
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   tournament_date_index_p2
# 0                      NaT
# 1                      NaT
# 2               2012-01-16
# 3                      NaT
# 4                      NaT

# %%
df_match_wide_train.loc[df_match_wide_train.Player_p1.isna()].shape
# Out:
# (251, 52)

# %%
df_match_wide_train.loc[df_match_wide_train.Player_p1.isna(),'Tournament_Date'].value_counts()
# Out:
# 2012-01-16    128
# 2012-05-28     23
# 2014-01-13     22
# 2013-01-14     19
# 2013-05-27     10
# 2018-01-15     10
# 2015-01-19      7
# 2017-05-29      7
# 2018-05-28      6
# 2017-01-16      5
# 2016-01-18      5
# 2014-05-26      4
# 2016-05-23      3
# 2015-05-25      2
# Name: Tournament_Date, dtype: int64

# %%
df_match_wide_train.loc[
    (df_match_wide_train.Player_p1.isna())
    & (df_match_wide_train.Tournament_Date=='2018-01-15')
].head()
# Out:
#                      Winner            Loser                  Tournament  \
# 2862          Stefan Kozlov      Blake Ellis  Australian Open, Melbourne
# 2867                  Di Wu      Dayne Kelly  Australian Open, Melbourne
# 2870           Bjorn Propst   Facundo Bagnis  Australian Open, Melbourne
# 2879        Carlos Taberner    Joao Monteiro  Australian Open, Melbourne
# 2888  Karim-Mohamed Maamoun  Marcelo Arevalo  Australian Open, Melbourne
#
#      Tournament_Date  player_1_win    randomised_player_1 randomised_player_2  \
# 2862      2018-01-15             0            Blake Ellis       Stefan Kozlov
# 2867      2018-01-15             0            Dayne Kelly               Di Wu
# 2870      2018-01-15             1           Bjorn Propst      Facundo Bagnis
# 2879      2018-01-15             1        Carlos Taberner       Joao Monteiro
# 2888      2018-01-15             1  Karim-Mohamed Maamoun     Marcelo Arevalo
#
#       random_number Player_p1  Player_Rank_p1  Player_Sets_Won_p1  \
# 2862              1       NaN             NaN                 NaN
# 2867              1       NaN             NaN                 NaN
# 2870              0       NaN             NaN                 NaN
# 2879              0       NaN             NaN                 NaN
# 2888              0       NaN             NaN                 NaN
#
#       Player_Games_Won_p1  Player_Aces_p1  Player_DoubleFaults_p1  \
# 2862                  NaN             NaN                     NaN
# 2867                  NaN             NaN                     NaN
# 2870                  NaN             NaN                     NaN
# 2879                  NaN             NaN                     NaN
# 2888                  NaN             NaN                     NaN
#
#       Player_FirstServes_Won_p1  Player_FirstServes_In_p1  \
# 2862                        NaN                       NaN
# 2867                        NaN                       NaN
# 2870                        NaN                       NaN
# 2879                        NaN                       NaN
# 2888                        NaN                       NaN
#
#       Player_SecondServes_Won_p1  Player_SecondServes_In_p1  \
# 2862                         NaN                        NaN
# 2867                         NaN                        NaN
# 2870                         NaN                        NaN
# 2879                         NaN                        NaN
# 2888                         NaN                        NaN
#
#       Player_BreakPoints_Won_p1  Player_BreakPoints_p1  \
# 2862                        NaN                    NaN
# 2867                        NaN                    NaN
# 2870                        NaN                    NaN
# 2879                        NaN                    NaN
# 2888                        NaN                    NaN
#
#       Player_ReturnPoints_Won_p1  Player_ReturnPoints_Faced_p1  \
# 2862                         NaN                           NaN
# 2867                         NaN                           NaN
# 2870                         NaN                           NaN
# 2879                         NaN                           NaN
# 2888                         NaN                           NaN
#
#       Player_TotalPoints_Won_p1  Total_Games_p1  won_p1  \
# 2862                        NaN             NaN     NaN
# 2867                        NaN             NaN     NaN
# 2870                        NaN             NaN     NaN
# 2879                        NaN             NaN     NaN
# 2888                        NaN             NaN     NaN
#
#       F_Player_Serve_Win_Ratio_p1  F_Player_Return_Win_Ratio_p1  \
# 2862                          NaN                           NaN
# 2867                          NaN                           NaN
# 2870                          NaN                           NaN
# 2879                          NaN                           NaN
# 2888                          NaN                           NaN
#
#       F_Player_BreakPoints_Per_Return_Game_p1  \
# 2862                                      NaN
# 2867                                      NaN
# 2870                                      NaN
# 2879                                      NaN
# 2888                                      NaN
#
#       F_Player_Game_Win_Percentage_p1 tournament_date_index_p1  \
# 2862                              NaN                      NaT
# 2867                              NaN                      NaT
# 2870                              NaN                      NaT
# 2879                              NaN                      NaT
# 2888                              NaN                      NaT
#
#             Player_p2  Player_Rank_p2  Player_Sets_Won_p2  \
# 2862    Stefan Kozlov      185.285714            0.741935
# 2867            Di Wu      216.666667            0.738095
# 2870   Facundo Bagnis      115.388060            0.940299
# 2879              NaN             NaN                 NaN
# 2888  Marcelo Arevalo      219.333333            0.500000
#
#       Player_Games_Won_p2  Player_Aces_p2  Player_DoubleFaults_p2  \
# 2862             9.258065        2.903226                4.354839
# 2867             9.309524        2.071429                2.595238
# 2870            10.776119        4.283582                3.313433
# 2879                  NaN             NaN                     NaN
# 2888             9.666667        4.666667                3.000000
#
#       Player_FirstServes_Won_p2  Player_FirstServes_In_p2  \
# 2862                  24.645161                 37.645161
# 2867                  25.404762                 39.547619
# 2870                  31.761194                 46.656716
# 2879                        NaN                       NaN
# 2888                  26.333333                 40.000000
#
#       Player_SecondServes_Won_p2  Player_SecondServes_In_p2  \
# 2862                   13.064516                  29.612903
# 2867                   13.428571                  28.238095
# 2870                   13.850746                  28.358209
# 2879                         NaN                        NaN
# 2888                   14.666667                  26.166667
#
#       Player_BreakPoints_Won_p2  Player_BreakPoints_p2  \
# 2862                   2.709677               6.290323
# 2867                   2.428571               5.880952
# 2870                   2.238806               5.865672
# 2879                        NaN                    NaN
# 2888                   1.666667               3.666667
#
#       Player_ReturnPoints_Won_p2  Player_ReturnPoints_Faced_p2  \
# 2862                   25.833333                     67.766667
# 2867                   23.850000                     64.250000
# 2870                   26.112903                     72.080645
# 2879                         NaN                           NaN
# 2888                   22.166667                     66.500000
#
#       Player_TotalPoints_Won_p2  Total_Games_p2    won_p2  \
# 2862                  63.548387       21.516129  0.258065
# 2867                  62.571429       20.785714  0.309524
# 2870                  71.925373       22.895522  0.388060
# 2879                        NaN             NaN       NaN
# 2888                  63.166667       22.000000  0.166667
#
#       F_Player_Serve_Win_Ratio_p2  F_Player_Return_Win_Ratio_p2  \
# 2862                     0.457146                      0.368718
# 2867                     0.511376                      0.364905
# 2870                     0.537059                      0.354205
# 2879                          NaN                           NaN
# 2888                     0.578711                      0.337123
#
#       F_Player_BreakPoints_Per_Return_Game_p2  \
# 2862                                 0.279110
# 2867                                 0.282258
# 2870                                 0.252306
# 2879                                      NaN
# 2888                                 0.187079
#
#       F_Player_Game_Win_Percentage_p2 tournament_date_index_p2
# 2862                         0.416452               2018-01-15
# 2867                         0.443278               2018-01-15
# 2870                         0.458755               2018-01-15
# 2879                              NaN                      NaT
# 2888                         0.449343               2018-01-15

# %%
df_match_long.loc[df_match_long.Player=='Dayne Kelly']
# Out:
#             Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 17915  Dayne Kelly        274.0              0.0                 7
#
#        Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 17915          1.0                  5.0                    23.0
#
#        Player_FirstServes_In  Player_SecondServes_Won  Player_SecondServes_In  \
# 17915                   41.0                     12.0                    31.0
#
#        Player_BreakPoints_Won  Player_BreakPoints  Player_ReturnPoints_Won  \
# 17915                     2.0                 4.0                     24.0
#
#        Player_ReturnPoints_Faced  Player_TotalPoints_Won  \
# 17915                       66.0                      59
#
#                        Tournament Tournament_Date Court_Surface  \
# 17915  Australian Open, Melbourne      2018-01-15          Hard
#
#       Round_Description  Total_Games  won  F_Player_Serve_Win_Ratio  \
# 17915        Qualifying           20    0                   0.38961
#
#        F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 17915                   0.363636                                   0.2
#
#        F_Player_Game_Win_Percentage
# 17915                          0.35

# %%
df_result_long.loc[df_result_long.Player=='Dayne Kelly']
# Out:
#            Player  Player_Rank  Player_Sets_Won  Player_Games_Won  \
# 7010  Dayne Kelly        274.0              0.0               7.0
#
#       Player_Aces  Player_DoubleFaults  Player_FirstServes_Won  \
# 7010          1.0                  5.0                    23.0
#
#       Player_FirstServes_In  Player_SecondServes_Won  Player_SecondServes_In  \
# 7010                   41.0                     12.0                    31.0
#
#       Player_BreakPoints_Won  Player_BreakPoints  Player_ReturnPoints_Won  \
# 7010                     2.0                 4.0                     24.0
#
#       Player_ReturnPoints_Faced  Player_TotalPoints_Won  Total_Games  won  \
# 7010                       66.0                    59.0         20.0  0.0
#
#       F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 7010                   0.38961                   0.363636
#
#       F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage  \
# 7010                                   0.2                          0.35
#
#      tournament_date_index
# 7010            2018-05-28

# %%
df_match_wide_train.head()
# Out:
#                      Winner               Loser                  Tournament  \
# 0  Adrian Menendez-Maceiras  Alejandro Gonzalez  Australian Open, Melbourne
# 1            Marco Crugnola      Amir Weintraub  Australian Open, Melbourne
# 2              Sergei Bubka      Andre Begemann  Australian Open, Melbourne
# 3           Denys Molchanov       Andrew Harris  Australian Open, Melbourne
# 4                Bjorn Phau      Arnaud Clement  Australian Open, Melbourne
#
#   Tournament_Date  player_1_win       randomised_player_1 randomised_player_2  \
# 0      2012-01-16             1  Adrian Menendez-Maceiras  Alejandro Gonzalez
# 1      2012-01-16             1            Marco Crugnola      Amir Weintraub
# 2      2012-01-16             0            Andre Begemann        Sergei Bubka
# 3      2012-01-16             0             Andrew Harris     Denys Molchanov
# 4      2012-01-16             0            Arnaud Clement          Bjorn Phau
#
#    random_number Player_p1  Player_Rank_p1  Player_Sets_Won_p1  \
# 0              0       NaN             NaN                 NaN
# 1              0       NaN             NaN                 NaN
# 2              1       NaN             NaN                 NaN
# 3              1       NaN             NaN                 NaN
# 4              1       NaN             NaN                 NaN
#
#    Player_Games_Won_p1  Player_Aces_p1  Player_DoubleFaults_p1  \
# 0                  NaN             NaN                     NaN
# 1                  NaN             NaN                     NaN
# 2                  NaN             NaN                     NaN
# 3                  NaN             NaN                     NaN
# 4                  NaN             NaN                     NaN
#
#    Player_FirstServes_Won_p1  Player_FirstServes_In_p1  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    Player_SecondServes_Won_p1  Player_SecondServes_In_p1  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Player_BreakPoints_Won_p1  Player_BreakPoints_p1  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    Player_ReturnPoints_Won_p1  Player_ReturnPoints_Faced_p1  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    Player_TotalPoints_Won_p1  Total_Games_p1  won_p1  \
# 0                        NaN             NaN     NaN
# 1                        NaN             NaN     NaN
# 2                        NaN             NaN     NaN
# 3                        NaN             NaN     NaN
# 4                        NaN             NaN     NaN
#
#    F_Player_Serve_Win_Ratio_p1  F_Player_Return_Win_Ratio_p1  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    F_Player_BreakPoints_Per_Return_Game_p1  F_Player_Game_Win_Percentage_p1  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   tournament_date_index_p1     Player_p2  Player_Rank_p2  Player_Sets_Won_p2  \
# 0                      NaT           NaN             NaN                 NaN
# 1                      NaT           NaN             NaN                 NaN
# 2                      NaT  Sergei Bubka           148.0                 1.0
# 3                      NaT           NaN             NaN                 NaN
# 4                      NaT           NaN             NaN                 NaN
#
#    Player_Games_Won_p2  Player_Aces_p2  Player_DoubleFaults_p2  \
# 0                  NaN             NaN                     NaN
# 1                  NaN             NaN                     NaN
# 2                  8.0             5.0                     4.0
# 3                  NaN             NaN                     NaN
# 4                  NaN             NaN                     NaN
#
#    Player_FirstServes_Won_p2  Player_FirstServes_In_p2  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                       26.0                      46.0
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    Player_SecondServes_Won_p2  Player_SecondServes_In_p2  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                        11.0                       26.0
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Player_BreakPoints_Won_p2  Player_BreakPoints_p2  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        2.0                    8.0
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#    Player_ReturnPoints_Won_p2  Player_ReturnPoints_Faced_p2  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                        25.0                          73.0
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    Player_TotalPoints_Won_p2  Total_Games_p2  won_p2  \
# 0                        NaN             NaN     NaN
# 1                        NaN             NaN     NaN
# 2                       62.0            24.0     0.0
# 3                        NaN             NaN     NaN
# 4                        NaN             NaN     NaN
#
#    F_Player_Serve_Win_Ratio_p2  F_Player_Return_Win_Ratio_p2  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                     0.434211                      0.342466
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    F_Player_BreakPoints_Per_Return_Game_p2  F_Player_Game_Win_Percentage_p2  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                 0.333333                         0.333333
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   tournament_date_index_p2
# 0                      NaT
# 1                      NaT
# 2               2012-01-16
# 3                      NaT
# 4                      NaT

# %%
df_match_wide_train['p1_na_flag'] = np.where(df_match_wide_train.Player_p1.isna(),1,0)
df_match_wide_train['p2_na_flag'] = np.where(df_match_wide_train.Player_p2.isna(),1,0)

# %%
rolling_cols
# Out:
# ['Player_Rank',
#  'Player_Sets_Won',
#  'Player_Games_Won',
#  'Player_Aces',
#  'Player_DoubleFaults',
#  'Player_FirstServes_Won',
#  'Player_FirstServes_In',
#  'Player_SecondServes_Won',
#  'Player_SecondServes_In',
#  'Player_BreakPoints_Won',
#  'Player_BreakPoints',
#  'Player_ReturnPoints_Won',
#  'Player_ReturnPoints_Faced',
#  'Player_TotalPoints_Won',
#  'Total_Games',
#  'won',
#  'F_Player_Serve_Win_Ratio',
#  'F_Player_Return_Win_Ratio',
#  'F_Player_BreakPoints_Per_Return_Game',
#  'F_Player_Game_Win_Percentage']

# %%
df_p1 = df_match_wide_train[['Player_Rank_p1', 'Player_Sets_Won_p1',
       'Player_Games_Won_p1', 'Player_Aces_p1', 'Player_DoubleFaults_p1',
       'Player_FirstServes_Won_p1', 'Player_FirstServes_In_p1',
       'Player_SecondServes_Won_p1', 'Player_SecondServes_In_p1',
       'Player_BreakPoints_Won_p1', 'Player_BreakPoints_p1',
       'Player_ReturnPoints_Won_p1', 'Player_ReturnPoints_Faced_p1',
       'Player_TotalPoints_Won_p1', 'Total_Games_p1', 'won_p1',
       'F_Player_Serve_Win_Ratio_p1', 'F_Player_Return_Win_Ratio_p1',
       'F_Player_BreakPoints_Per_Return_Game_p1',
       'F_Player_Game_Win_Percentage_p1']].fillna(-1)

df_p2 = df_match_wide_train[['Player_Rank_p2', 'Player_Sets_Won_p2',
       'Player_Games_Won_p2', 'Player_Aces_p2', 'Player_DoubleFaults_p2',
       'Player_FirstServes_Won_p2', 'Player_FirstServes_In_p2',
       'Player_SecondServes_Won_p2', 'Player_SecondServes_In_p2',
       'Player_BreakPoints_Won_p2', 'Player_BreakPoints_p2',
       'Player_ReturnPoints_Won_p2', 'Player_ReturnPoints_Faced_p2',
       'Player_TotalPoints_Won_p2', 'Total_Games_p2', 'won_p2',
       'F_Player_Serve_Win_Ratio_p2', 'F_Player_Return_Win_Ratio_p2',
       'F_Player_BreakPoints_Per_Return_Game_p2',
       'F_Player_Game_Win_Percentage_p2']].fillna(-1)

df_p1.columns = rolling_cols
df_p2.columns = rolling_cols

# %%
df_diff = df_p1- df_p2

# %%
df_p1.tail(2)
# Out:
#       Player_Rank  Player_Sets_Won  Player_Games_Won  Player_Aces  \
# 3327   118.220339         0.847458         10.406780     3.457627
# 3328     3.785542         1.959036         14.240964     2.915663
#
#       Player_DoubleFaults  Player_FirstServes_Won  Player_FirstServes_In  \
# 3327             2.355932               32.322034              48.457627
# 3328             1.603865               35.708434              49.342169
#
#       Player_SecondServes_Won  Player_SecondServes_In  Player_BreakPoints_Won  \
# 3327                11.457627               24.644068                2.067797
# 3328                12.691566               22.274699                4.000000
#
#       Player_BreakPoints  Player_ReturnPoints_Won  Player_ReturnPoints_Faced  \
# 3327            5.559322                24.785714                  71.250000
# 3328            8.836145                32.756627                  76.568675
#
#       Player_TotalPoints_Won  Total_Games       won  F_Player_Serve_Win_Ratio  \
# 3327               68.305085    23.016949  0.305085                  0.547021
# 3328               81.214458    23.568675  0.833735                  0.649959
#
#       F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 3327                   0.343780                              0.243822
# 3328                   0.438925                              0.400675
#
#       F_Player_Game_Win_Percentage
# 3327                      0.450930
# 3328                      0.624391

# %%
df_p2.tail(2)
# Out:
#       Player_Rank  Player_Sets_Won  Player_Games_Won  Player_Aces  \
# 3327    31.848684         1.539474         13.299342     5.845395
# 3328    31.848684         1.539474         13.299342     5.845395
#
#       Player_DoubleFaults  Player_FirstServes_Won  Player_FirstServes_In  \
# 3327             2.855263               33.845395              45.690789
# 3328             2.855263               33.845395              45.690789
#
#       Player_SecondServes_Won  Player_SecondServes_In  Player_BreakPoints_Won  \
# 3327                16.917763               31.782895                2.894737
# 3328                16.917763               31.782895                2.894737
#
#       Player_BreakPoints  Player_ReturnPoints_Won  Player_ReturnPoints_Faced  \
# 3327            7.710526                 30.76412                  81.448505
# 3328            7.710526                 30.76412                  81.448505
#
#       Player_TotalPoints_Won  Total_Games       won  F_Player_Serve_Win_Ratio  \
# 3327               81.611842    25.167763  0.644737                  0.601141
# 3328               81.611842    25.167763  0.644737                  0.601141
#
#       F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 3327                    0.37837                              0.315272
# 3328                    0.37837                              0.315272
#
#       F_Player_Game_Win_Percentage
# 3327                      0.532536
# 3328                      0.532536

# %%
df_diff.tail(2)
# Out:
#       Player_Rank  Player_Sets_Won  Player_Games_Won  Player_Aces  \
# 3327    86.371655        -0.692016         -2.892562    -2.387768
# 3328   -28.063142         0.419562          0.941622    -2.929732
#
#       Player_DoubleFaults  Player_FirstServes_Won  Player_FirstServes_In  \
# 3327            -0.499331               -1.523361               2.766838
# 3328            -1.251398                1.863039               3.651379
#
#       Player_SecondServes_Won  Player_SecondServes_In  Player_BreakPoints_Won  \
# 3327                -5.460136               -7.138827               -0.826940
# 3328                -4.226197               -9.508196                1.105263
#
#       Player_BreakPoints  Player_ReturnPoints_Won  Player_ReturnPoints_Faced  \
# 3327           -2.151204                -5.978405                 -10.198505
# 3328            1.125618                 1.992507                  -4.879830
#
#       Player_TotalPoints_Won  Total_Games       won  F_Player_Serve_Win_Ratio  \
# 3327              -13.306757    -2.150814 -0.339652                 -0.054120
# 3328               -0.397384    -1.599088  0.188998                  0.048819
#
#       F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 3327                  -0.034590                             -0.071450
# 3328                   0.060556                              0.085404
#
#       F_Player_Game_Win_Percentage
# 3327                     -0.081606
# 3328                      0.091855

# %%
drop_cols = ['Player_Rank_p1', 'Player_Sets_Won_p1',
       'Player_Games_Won_p1', 'Player_Aces_p1', 'Player_DoubleFaults_p1',
       'Player_FirstServes_Won_p1', 'Player_FirstServes_In_p1',
       'Player_SecondServes_Won_p1', 'Player_SecondServes_In_p1',
       'Player_BreakPoints_Won_p1', 'Player_BreakPoints_p1',
       'Player_ReturnPoints_Won_p1', 'Player_ReturnPoints_Faced_p1',
       'Player_TotalPoints_Won_p1', 'Total_Games_p1', 'won_p1',
       'F_Player_Serve_Win_Ratio_p1', 'F_Player_Return_Win_Ratio_p1',
       'F_Player_BreakPoints_Per_Return_Game_p1',
       'F_Player_Game_Win_Percentage_p1'] +  \
            ['Player_Rank_p2', 'Player_Sets_Won_p2',
       'Player_Games_Won_p2', 'Player_Aces_p2', 'Player_DoubleFaults_p2',
       'Player_FirstServes_Won_p2', 'Player_FirstServes_In_p2',
       'Player_SecondServes_Won_p2', 'Player_SecondServes_In_p2',
       'Player_BreakPoints_Won_p2', 'Player_BreakPoints_p2',
       'Player_ReturnPoints_Won_p2', 'Player_ReturnPoints_Faced_p2',
       'Player_TotalPoints_Won_p2', 'Total_Games_p2', 'won_p2',
       'F_Player_Serve_Win_Ratio_p2', 'F_Player_Return_Win_Ratio_p2',
       'F_Player_BreakPoints_Per_Return_Game_p2',
       'F_Player_Game_Win_Percentage_p2'] \
    +  ['random_number','Player_p1','tournament_date_index_p1','Player_p2','tournament_date_index_p2']

# %%
df_match_wide_train.drop(drop_cols, axis =1, inplace=True)

# %%
df_match_wide_train.head()
# Out:
#                      Winner               Loser                  Tournament  \
# 0  Adrian Menendez-Maceiras  Alejandro Gonzalez  Australian Open, Melbourne
# 1            Marco Crugnola      Amir Weintraub  Australian Open, Melbourne
# 2              Sergei Bubka      Andre Begemann  Australian Open, Melbourne
# 3           Denys Molchanov       Andrew Harris  Australian Open, Melbourne
# 4                Bjorn Phau      Arnaud Clement  Australian Open, Melbourne
#
#   Tournament_Date  player_1_win       randomised_player_1 randomised_player_2  \
# 0      2012-01-16             1  Adrian Menendez-Maceiras  Alejandro Gonzalez
# 1      2012-01-16             1            Marco Crugnola      Amir Weintraub
# 2      2012-01-16             0            Andre Begemann        Sergei Bubka
# 3      2012-01-16             0             Andrew Harris     Denys Molchanov
# 4      2012-01-16             0            Arnaud Clement          Bjorn Phau
#
#    p1_na_flag  p2_na_flag
# 0           1           1
# 1           1           1
# 2           1           0
# 3           1           1
# 4           1           1

# %%
df_match_wide_train.head()
# Out:
#                      Winner               Loser                  Tournament  \
# 0  Adrian Menendez-Maceiras  Alejandro Gonzalez  Australian Open, Melbourne
# 1            Marco Crugnola      Amir Weintraub  Australian Open, Melbourne
# 2              Sergei Bubka      Andre Begemann  Australian Open, Melbourne
# 3           Denys Molchanov       Andrew Harris  Australian Open, Melbourne
# 4                Bjorn Phau      Arnaud Clement  Australian Open, Melbourne
#
#   Tournament_Date  player_1_win       randomised_player_1 randomised_player_2  \
# 0      2012-01-16             1  Adrian Menendez-Maceiras  Alejandro Gonzalez
# 1      2012-01-16             1            Marco Crugnola      Amir Weintraub
# 2      2012-01-16             0            Andre Begemann        Sergei Bubka
# 3      2012-01-16             0             Andrew Harris     Denys Molchanov
# 4      2012-01-16             0            Arnaud Clement          Bjorn Phau
#
#    p1_na_flag  p2_na_flag
# 0           1           1
# 1           1           1
# 2           1           0
# 3           1           1
# 4           1           1

# %%
df_match_wide_train.shape
# Out:
# (3329, 9)

# %%
df_diff.shape
# Out:
# (3329, 20)

# %%
df_train = pd.concat([df_match_wide_train, df_diff], axis=1)

# %%
df_train.shape
# Out:
# (3329, 29)

# %%
df_train.columns
# Out:
# Index(['Winner', 'Loser', 'Tournament', 'Tournament_Date', 'player_1_win',
#        'randomised_player_1', 'randomised_player_2', 'p1_na_flag',
#        'p2_na_flag', 'Player_Rank', 'Player_Sets_Won', 'Player_Games_Won',
#        'Player_Aces', 'Player_DoubleFaults', 'Player_FirstServes_Won',
#        'Player_FirstServes_In', 'Player_SecondServes_Won',
#        'Player_SecondServes_In', 'Player_BreakPoints_Won',
#        'Player_BreakPoints', 'Player_ReturnPoints_Won',
#        'Player_ReturnPoints_Faced', 'Player_TotalPoints_Won', 'Total_Games',
#        'won', 'F_Player_Serve_Win_Ratio', 'F_Player_Return_Win_Ratio',
#        'F_Player_BreakPoints_Per_Return_Game', 'F_Player_Game_Win_Percentage'],
#       dtype='object')

# %%
df_valid = df_train.loc[(df_train.Tournament_Date == '2018-01-15') ]
df_train = df_train.loc[(df_train.Tournament_Date < '2018-01-15') & (df_train.Tournament_Date >= '2013-01-01')]

# %%
df_valid.shape
# Out:
# (235, 29)

# %%
df_train.shape
# Out:
# (2380, 29)

# %%
drop_col = ['Winner', 'Loser', 'Tournament', 'Tournament_Date','randomised_player_1', 'randomised_player_2']
df_train.drop(drop_col, axis=1, inplace=True)
df_valid.drop(drop_col, axis=1, inplace=True)

feats = [col for col in df_train.columns if col != 'player_1_win']
target= 'player_1_win'

# %%
X_train, y_train = df_train[feats],df_train[target]
X_valid, y_valid = df_valid[feats],df_valid[target]

# %%
import lightgbm


train_data_lgb = lightgbm.Dataset(X_train, label=y_train)
valid_data_lgb = lightgbm.Dataset(X_valid, label=y_valid)


gc.collect()

parameters = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    #'is_unbalance': 'true',
    #'scale_pos_weight': 400,
    #'device' : 'gpu' ,
    'boosting': 'gbdt',
    'num_leaves': 30, #31
    'feature_fraction': 0.7,
    'bagging_fraction': 0.7,
    'bagging_freq': 10,
    'learning_rate': 0.1, #0.05
    'verbose': 30
    #'min_data_in_leaf': 200
}


clf_LGB = lightgbm.train(parameters,
                         train_data_lgb,
                         #valid_sets=[valid_data_lgb,holdout_data_lgb],
                         valid_sets=[train_data_lgb,valid_data_lgb],
                         num_boost_round=1000,
                         early_stopping_rounds=30,
                         verbose_eval=10)
# Out:
# Training until validation scores don't improve for 30 rounds.
# [10]	training's binary_logloss: 0.549727	valid_1's binary_logloss: 0.670077
# [20]	training's binary_logloss: 0.481907	valid_1's binary_logloss: 0.678777
# [30]	training's binary_logloss: 0.434667	valid_1's binary_logloss: 0.686721
# Early stopping, best iteration is:
# [7]	training's binary_logloss: 0.576012	valid_1's binary_logloss: 0.665786

# %%
import shap

# load JS visualization code to notebook
shap.initjs()


# explain the model's predictions using SHAP values
# (same syntax works for LightGBM, CatBoost, and scikit-learn models)
explainer = shap.TreeExplainer(clf_LGB)
shap_values = explainer.shap_values(X_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){var e={};function n(r){if(e[r])return e[r].exports;var i=e[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,n),i.l=!0,i.exports}n.m=t,n.c=e,n.d=function(t,e,r){n.o(t,e)||Object.defineProperty(t,e,{enumerable:!0,get:r})},n.r=function(t){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},n.t=function(t,e){if(1&e&&(t=n(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var r=Object.create(null);if(n.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var i in t)n.d(r,i,function(e){return t[e]}.bind(null,i));return r},n.n=function(t){var e=t&&t.__esModule?function(){return t.default}:function(){return t};return n.d(e,"a",e),e},n.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},n.p="",n(n.s=90)}([function(t,e,n){"use strict";var r=new Date,i=new Date;function o(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return o(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,o){return r.setTime(+e),i.setTime(+o),t(r),t(i),Math.floor(n(r,i))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}var a=o(function(){},function(t,e){t.setTime(+t+e)},function(t,e){return e-t});a.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?o(function(e){e.setTime(Math.floor(e/t)*t)},function(e,n){e.setTime(+e+n*t)},function(e,n){return(n-e)/t}):a:null};var u=a,c=(a.range,6e4),s=6048e5,l=o(function(t){t.setTime(1e3*Math.floor(t/1e3))},function(t,e){t.setTime(+t+1e3*e)},function(t,e){return(e-t)/1e3},function(t){return t.getUTCSeconds()}),f=l,p=(l.range,o(function(t){t.setTime(Math.floor(t/c)*c)},function(t,e){t.setTime(+t+e*c)},function(t,e){return(e-t)/c},function(t){return t.getMinutes()})),h=p,d=(p.range,o(function(t){var e=t.getTimezoneOffset()*c%36e5;e<0&&(e+=36e5),t.setTime(36e5*Math.floor((+t-e)/36e5)+e)},function(t,e){t.setTime(+t+36e5*e)},function(t,e){return(e-t)/36e5},function(t){return t.getHours()})),v=d,g=(d.range,o(function(t){t.setHours(0,0,0,0)},function(t,e){t.setDate(t.getDate()+e)},function(t,e){return(e-t-(e.getTimezoneOffset()-t.getTimezoneOffset())*c)/864e5},function(t){return t.getDate()-1})),m=g;g.range;function y(t){return o(function(e){e.setDate(e.getDate()-(e.getDay()+7-t)%7),e.setHours(0,0,0,0)},function(t,e){t.setDate(t.getDate()+7*e)},function(t,e){return(e-t-(e.getTimezoneOffset()-t.getTimezoneOffset())*c)/s})}var _=y(0),b=y(1),x=y(2),w=y(3),C=y(4),k=y(5),E=y(6),T=(_.range,b.range,x.range,w.range,C.range,k.range,E.range,o(function(t){t.setDate(1),t.setHours(0,0,0,0)},function(t,e){t.setMonth(t.getMonth()+e)},function(t,e){return e.getMonth()-t.getMonth()+12*(e.getFullYear()-t.getFullYear())},function(t){return t.getMonth()})),M=T,S=(T.range,o(function(t){t.setMonth(0,1),t.setHours(0,0,0,0)},function(t,e){t.setFullYear(t.getFullYear()+e)},function(t,e){return e.getFullYear()-t.getFullYear()},function(t){return t.getFullYear()}));S.every=function(t){return isFinite(t=Math.floor(t))&&t>0?o(function(e){e.setFullYear(Math.floor(e.getFullYear()/t)*t),e.setMonth(0,1),e.setHours(0,0,0,0)},function(e,n){e.setFullYear(e.getFullYear()+n*t)}):null};var N=S,A=(S.range,o(function(t){t.setUTCSeconds(0,0)},function(t,e){t.setTime(+t ...

# %%
shap.summary_plot(shap_values, X_train)

# %%
shap.dependence_plot("Player_Rank", shap_values, X_train)

# %%
shap.dependence_plot("Player_Sets_Won", shap_values, X_train)
