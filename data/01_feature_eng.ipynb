# %%
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
import gc
import sys
import warnings
warnings.filterwarnings('ignore')
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import sqlite3
import pandas_profiling
#from common_function import *

pd.options.display.max_columns = 999
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns
    

def reduce_mem_usage(df_):
    start_mem = df_.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe: {:.2f} MB'.format(start_mem))
    
    for c in df_.columns[df_.dtypes != 'object']:
        col_type = df_[c].dtype
        
        c_min = df_[c].min()
        c_max = df_[c].max()
        if str(col_type)[:3] == 'int':
            if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                df_[c] = df_[c].astype(np.int8)
            elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                df_[c] = df_[c].astype(np.int16)
            elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                df_[c] = df_[c].astype(np.int32)
            else:
                df_[c] = df_[c].astype(np.int64)  
        else:
            if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                df_[c] = df_[c].astype(np.float16)
            elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                df_[c] = df_[c].astype(np.float32)
            else:
                df_[c] = df_[c].astype(np.float64)

    end_mem = df_.memory_usage().sum() / 1024**2
    print('Memory usage after optimization: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df_

# %%
# Load the csv 
df_match_wide = pd.read_csv("data/ATP_matches.csv")

# Store the shape of the data for reference check later
original_shape = df_match_wide.shape

# %%
# What are the big tournaments in the data
df_match_wide.Tournament.value_counts().head()
# Out:
# Australian Open, Melbourne    1665
# French Open, Paris            1664
# U.S. Open, New York           1662
# Wimbledon, London             1106
# Indian Wells                   653
# Name: Tournament, dtype: int64

# %%
missing_values_table(df_match_wide)
# Out:
# Your selected dataframe has 35 columns.
# There are 1 columns that have missing values.
#                    Missing Values  % of Total Values
# Round_Description              34                0.2

# %%
df_match_wide.head(2)
# Out:
#                    Winner          Loser Tournament Tournament_Date  \
# 0  Edouard Roger-Vasselin    Eric Prodon    Chennai        2-Jan-12
# 1               Dudi Sela  Fabio Fognini    Chennai        2-Jan-12
#
#   Court_Surface Round_Description Winner_Rank Loser_Rank  Retirement_Ind  \
# 0          Hard       First Round         106         97               0
# 1          Hard       First Round          83         48               0
#
#   Winner_Sets_Won  Winner_Games_Won Winner_Aces Winner_DoubleFaults  \
# 0               2                12           5                   2
# 1               2                12           2                   0
#
#   Winner_FirstServes_Won Winner_FirstServes_In Winner_SecondServes_Won  \
# 0                     22                    30                      12
# 1                     14                    17                      11
#
#   Winner_SecondServes_In Winner_BreakPoints_Won Winner_BreakPoints  \
# 0                     19                      4                  7
# 1                     16                      6                 14
#
#   Winner_ReturnPoints_Won Winner_ReturnPoints_Faced  Winner_TotalPoints_Won  \
# 0                      25                        59                      59
# 1                      36                        58                      61
#
#   Loser_Sets_Won  Loser_Games_Won Loser_Aces Loser_DoubleFaults  \
# 0              0                7          2                  3
# 1              0                1          1                  4
#
#   Loser_FirstServes_Won Loser_FirstServes_In Loser_SecondServes_Won  \
# 0                    21                   33                     13
# 1                    17                   32                      5
#
#   Loser_SecondServes_In Loser_BreakPoints_Won Loser_BreakPoints  \
# 0                    26                     1                 3
# 1                    26                     0                 1
#
#   Loser_ReturnPoints_Won Loser_ReturnPoints_Faced  Loser_TotalPoints_Won
# 0                     15                       49                     49
# 1                      8                       33                     30

# %%
df_match_wide.Tournament_Date = pd.to_datetime(df_match_wide.Tournament_Date,dayfirst=True)

# %%
df_match_wide['Total_Games'] = df_match_wide.Winner_Games_Won + df_match_wide.Loser_Games_Won

# %%
winner_cols = ['Winner', 'Tournament', 'Tournament_Date', 'Court_Surface',
       'Round_Description', 'Winner_Rank', 'Retirement_Ind',
       'Winner_Sets_Won', 'Winner_Games_Won', 'Winner_Aces',
       'Winner_DoubleFaults', 'Winner_FirstServes_Won',
       'Winner_FirstServes_In', 'Winner_SecondServes_Won',
       'Winner_SecondServes_In', 'Winner_BreakPoints_Won',
       'Winner_BreakPoints', 'Winner_ReturnPoints_Won',
       'Winner_ReturnPoints_Faced', 'Winner_TotalPoints_Won','Total_Games']
loser_cols = ['Loser', 'Tournament', 'Tournament_Date', 'Court_Surface',
       'Round_Description', 'Loser_Rank', 'Retirement_Ind',
        'Loser_Sets_Won','Loser_Games_Won', 'Loser_Aces', 'Loser_DoubleFaults',
       'Loser_FirstServes_Won', 'Loser_FirstServes_In',
       'Loser_SecondServes_Won', 'Loser_SecondServes_In',
       'Loser_BreakPoints_Won', 'Loser_BreakPoints', 'Loser_ReturnPoints_Won',
       'Loser_ReturnPoints_Faced', 'Loser_TotalPoints_Won','Total_Games']
df_winner = df_match_wide[winner_cols]

df_loser = df_match_wide[loser_cols]

df_winner["won"] = 1
df_loser["won"] = 0

# Rename the columns so that they are the same for winners and losers
df_winner.columns = ['Player', 'Tournament', 'Tournament_Date', 'Court_Surface',
       'Round_Description', 'Rank', 'Retirement_Ind',
        'Sets_Won','Games_Won', 'Aces', 'DoubleFaults',
       'FirstServes_Won', 'FirstServes_In',
       'SecondServes_Won', 'SecondServes_In',
       'BreakPoints_Won', 'BreakPoints', 'ReturnPoints_Won',
       'ReturnPoints_Faced', 'TotalPoints_Won',"won",'Total_Games']

# Rename the columns so that they are the same for winners and losers
df_loser.columns = df_winner.columns

# %%
# append the winner and loser dfs together so now the dataframe is in long format

df_match_long = df_winner.append(df_loser)

# %%
# The long table should have exactly twice of the rows of the original data
assert df_match_long.shape[0] == original_shape[0]*2

# %%
# Get the dates of the aus open
aus_open_dates = df_match_wide.loc[df_match_wide.Tournament=='Australian Open, Melbourne'].groupby(['Tournament','Tournament_Date'])['Winner'].count().reset_index()

aus_open_dates
# Out:
#                    Tournament Tournament_Date  Winner
# 0  Australian Open, Melbourne      2012-01-16     237
# 1  Australian Open, Melbourne      2013-01-14     239
# 2  Australian Open, Melbourne      2014-01-13     238
# 3  Australian Open, Melbourne      2015-01-19     238
# 4  Australian Open, Melbourne      2016-01-18     239
# 5  Australian Open, Melbourne      2017-01-16     239
# 6  Australian Open, Melbourne      2018-01-15     235

# %%
# 'Australian Open, Melbourne'    
# # 'French Open, Paris'            
# # 'U.S. Open, New York '          
# # 'Wimbledon, London'

# %%
# some cells have . but we will convert them into null
df_match_long = df_match_long.replace('.', np.nan)

stats_cols = ['Rank', 'Retirement_Ind', 'Sets_Won', 'Games_Won',
       'Aces', 'DoubleFaults', 'FirstServes_Won', 'FirstServes_In',
       'SecondServes_Won', 'SecondServes_In', 'BreakPoints_Won', 'BreakPoints',
       'ReturnPoints_Won', 'ReturnPoints_Faced', 'TotalPoints_Won', 'won',]

df_match_long[stats_cols] = df_match_long[stats_cols].apply(pd.to_numeric)


df_match_long = df_match_long.sort_values(['Player','Tournament_Date','Tournament'], ascending=True)

# %%
# df_player = get_feature_period(df_player)

# %%
df_match_long['Total_Games'] = df_match_long.FirstServes_Won
df_match_long['F_Player_Serve_Win_Ratio'] = (df_match_long.FirstServes_Won + df_match_long.SecondServes_Won - df_match_long.DoubleFaults)/(df_match_long.FirstServes_In + df_match_long.SecondServes_In + df_match_long.DoubleFaults)# Point Win ratio when serving
df_match_long['F_Player_Return_Win_Ratio'] = df_match_long.ReturnPoints_Won / df_match_long.ReturnPoints_Faced # Point win ratio when returning
df_match_long['F_Player_BreakPoints_Per_Return_Game'] = df_match_long.BreakPoints/df_match_long.Total_Games  # Breakpoints per receiving game
df_match_long['F_Player_Game_Win_Percentage'] = df_match_long.Games_Won/df_match_long.Total_Games

# %%
df_match_long.columns
# Out:
# Index(['Player', 'Tournament', 'Tournament_Date', 'Court_Surface',
#        'Round_Description', 'Rank', 'Retirement_Ind', 'Sets_Won', 'Games_Won',
#        'Aces', 'DoubleFaults', 'FirstServes_Won', 'FirstServes_In',
#        'SecondServes_Won', 'SecondServes_In', 'BreakPoints_Won', 'BreakPoints',
#        'ReturnPoints_Won', 'ReturnPoints_Faced', 'TotalPoints_Won', 'won',
#        'Total_Games', 'F_Player_Serve_Win_Ratio', 'F_Player_Return_Win_Ratio',
#        'F_Player_BreakPoints_Per_Return_Game', 'F_Player_Game_Win_Percentage'],
#       dtype='object')

# %%
def get_rolling_features (df):
    
    # Need to sort the data first so its from old to recent
    df = df.sort_values(['Player','Tournament_Date','Tournament'], ascending=True)
    
    
    # columns we are taking rolling averages from
    num_cols = ['Rank', 'Retirement_Ind', 'Sets_Won', 'Games_Won',
       'Aces', 'DoubleFaults', 'FirstServes_Won', 'FirstServes_In',
       'SecondServes_Won', 'SecondServes_In', 'BreakPoints_Won', 'BreakPoints',
       'ReturnPoints_Won', 'ReturnPoints_Faced', 'TotalPoints_Won', 'won','F_Player_Serve_Win_Ratio',
       'F_Player_Return_Win_Ratio', 'F_Player_BreakPoints_Per_Return_Game',
       'F_Player_Game_Win_Percentage']
    
    # For each year, get the rolling averages of that player's past matches before the tournament start date
    for index, tournament_date in enumerate(aus_open_dates.Tournament_Date):
    
        # create a temp df to store the intrim results
        df_temp = df.loc[df.Tournament_Date < tournament_date]

        # take the most recent 20 matches for the rolling average
        df_temp = df_temp.groupby('Player')[num_cols].rolling(20, min_periods=1).mean().reset_index()
        df_temp = df_temp.groupby('Player').tail(1)

        if index ==0:
            # create the result dataframe
            df_result = df_temp
            # so we know which tournament this feature is for
            df_result['tournament_date_index'] = tournament_date
        else:
            df_temp['tournament_date_index'] = tournament_date
            df_result = df_result.append(df_temp)
    df_result.drop('level_1', axis=1,inplace=True)
    
    return df_result

# %%
# df_feature = pd.DataFrame()

# df_player = df_player.copy()

# num_cols = ['Rank', 'Retirement_Ind', 'Sets_Won', 'Games_Won',
#        'Aces', 'DoubleFaults', 'FirstServes_Won', 'FirstServes_In',
#        'SecondServes_Won', 'SecondServes_In', 'BreakPoints_Won', 'BreakPoints',
#        'ReturnPoints_Won', 'ReturnPoints_Faced', 'TotalPoints_Won', 'won','F_Player_Serve_Win_Ratio',
#        'F_Player_Return_Win_Ratio', 'F_Player_BreakPoints_Per_Return_Game',
#        'F_Player_Game_Win_Percentage']

# for index, year in enumerate(aus_open_dates.Tournament_Date):
    
#     df_year = df_test.loc[df_test.Tournament_Date < year]
    
#     df_year = df_year.groupby('Player')[num_cols].rolling(20, min_periods=1).mean().reset_index()
#     df_year = df_year.groupby('Player').tail(1)
#     #df_year = df_year.groupby('Player')[num_cols].mean().reset_index()
#     if index ==0:
#         df_new = df_year
#         df_new['year'] = year
#     else:
#         df_year['year'] = year
#         df_new = df_new.append(df_year)
        
    
    
df_result_long = get_rolling_features (df_match_long)

# %%
df_match_long.shape
# Out:
# (41614, 26)

# %%
#df_match_long = df_match_long.sort_values(['Player','Tournament_Date'])

# %%
# check some of the matches

# %%
# df_match_open = df_match.loc[df_match.Tournament=='Australian Open, Melbourne',['Winner','Loser','Tournament_Date']] 

# df_wide = df_match_open.merge(df_new, left_on=['Winner','Tournament_Date'], right_on = ['Player','year'],how='left',validate ='m:1')

# %%
df_match_long.head(20)
# Out:
#               Player                  Tournament Tournament_Date  \
# 3121     Adam Feeney  Australian Open, Melbourne      2013-01-14
# 3173     Adam Feeney  Australian Open, Melbourne      2013-01-14
# 8917   Adam Pavlasek  Australian Open, Melbourne      2015-01-19
# 8978   Adam Pavlasek  Australian Open, Melbourne      2015-01-19
# 11062  Adam Pavlasek         U.S. Open, New York      2015-08-31
# 13080  Adam Pavlasek          French Open, Paris      2016-05-23
# 13131  Adam Pavlasek          French Open, Paris      2016-05-23
# 13214  Adam Pavlasek          French Open, Paris      2016-05-23
# 13149  Adam Pavlasek          French Open, Paris      2016-05-23
# 13229  Adam Pavlasek          French Open, Paris      2016-05-23
# 13717  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 13725  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 13729  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 14549  Adam Pavlasek                   Stockholm      2016-10-17
# 14966  Adam Pavlasek  Australian Open, Melbourne      2017-01-16
# 15400  Adam Pavlasek                       Dubai      2017-02-27
# 15524  Adam Pavlasek                       Miami      2017-03-20
# 15643  Adam Pavlasek                     Houston      2017-04-10
# 16038  Adam Pavlasek          French Open, Paris      2017-05-29
# 16571  Adam Pavlasek           Wimbledon, London      2017-07-03
#
#       Court_Surface Round_Description   Rank  Retirement_Ind  Sets_Won  \
# 3121           Hard        Qualifying  327.0               0       2.0
# 3173           Hard        Qualifying  327.0               0       0.0
# 8917           Hard        Qualifying  240.0               0       2.0
# 8978           Hard        Qualifying  240.0               0       1.0
# 11062          Hard        Qualifying  149.0               0       0.0
# 13080          Clay        Qualifying  132.0               0       2.0
# 13131          Clay        Qualifying  132.0               0       2.0
# 13214          Clay       First Round  132.0               0       3.0
# 13149          Clay        Qualifying  132.0               0       1.0
# 13229          Clay      Second Round  132.0               0       0.0
# 13717          Clay       First Round  116.0               0       2.0
# 13725          Clay      Second Round  116.0               0       2.0
# 13729          Clay    Quarter-finals  116.0               0       1.0
# 14549   Indoor Hard       First Round   89.0               0       0.0
# 14966          Hard       First Round   86.0               0       1.0
# 15400          Hard       First Round   93.0               0       0.0
# 15524          Hard       First Round   96.0               0       0.0
# 15643          Clay       First Round   98.0               0       1.0
# 16038          Clay        Qualifying   97.0               0       1.0
# 16571         Grass       First Round  136.0               0       3.0
#
#        Games_Won  Aces  DoubleFaults  FirstServes_Won  FirstServes_In  \
# 3121          17   0.0           8.0             42.0            63.0
# 3173           9   1.0           2.0             33.0            54.0
# 8917          13   5.0           1.0             28.0            37.0
# 8978          11  18.0          10.0             66.0            95.0
# 11062          7   2.0           1.0             17.0            31.0
# 13080         15   9.0           3.0             42.0            66.0
# 13131         12   3.0           0.0             23.0            27.0
# 13214         23   7.0           2.0             66.0           102.0
# 13149         10   2.0           2.0             33.0            51.0
# 13229         10   5.0           4.0             42.0            55.0
# 13717         12   3.0           4.0             25.0            30.0
# 13725         12   6.0           2.0             24.0            32.0
# 13729         16   9.0           5.0             45.0            66.0
# 14549          8   6.0           3.0             29.0            42.0
# 14966         15  13.0           3.0             47.0            66.0
# 15400          4   5.0           3.0             19.0            33.0
# 15524          5   3.0           3.0             17.0            31.0
# 15643         10   5.0           5.0             29.0            47.0
# 16038         13   5.0           4.0             27.0            40.0
# 16571         24  14.0           5.0             59.0            70.0
#
#        SecondServes_Won  SecondServes_In  BreakPoints_Won  BreakPoints  \
# 3121               19.0             33.0              4.0         19.0
# 3173                7.0             24.0              3.0          7.0
# 8917               15.0             25.0              3.0          7.0
# 8978               38.0             78.0              2.0          5.0
# 11062              17.0             30.0              1.0          1.0
# 13080              15.0             30.0              5.0         11.0
# 13131              11.0             16.0              4.0          6.0
# 13214              26.0             53.0              8.0         17.0
# 13149              11.0             31.0              2.0          4.0
# 13229              12.0             29.0              0.0          0.0
# 13717              20.0             34.0              2.0          6.0
# 13725              14.0             25.0              4.0          5.0
# 13729              23.0             48.0              2.0          2.0
# 14549              12.0             26.0              1.0          6.0
# 14966              16.0             41.0              2.0          7.0
# 15400               6.0             22.0              1.0          2.0
# 15524              11.0             30.0              2.0          2.0
# 15643              18.0             40.0              2.0          2.0
# 16038              21.0             39.0              4.0         14.0
# 16571              17.0             33.0              8.0         18.0
#
#        ReturnPoints_Won  ReturnPoints_Faced  TotalPoints_Won  won  \
# 3121               48.0               115.0              109   31
# 3173               29.0                75.0               69   22
# 8917                NaN                 NaN               71   20
# 8978                NaN                 NaN              147   27
# 11062               NaN                 NaN               52   20
# 13080              40.0                88.0               97   28
# 13131              23.0                47.0               57   16
# 13214              61.0               135.0              153   41
# 13149              26.0                71.0               70   25
# 13229              11.0                67.0               65   28
# 13717              25.0                60.0               70   19
# 13725              21.0                45.0               59   18
# 13729              30.0                99.0               98   34
# 14549              24.0                72.0               65   21
# 14966              37.0               112.0              100   37
# 15400              17.0                50.0               42   16
# 15524              15.0                45.0               43   17
# 15643              22.0                68.0               69   27
# 16038              40.0                97.0               88   27
# 16571              55.0               127.0              131   36
#
#        Total_Games  F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 3121          42.0                  0.509615                   0.417391
# 3173          33.0                  0.475000                   0.386667
# 8917          28.0                  0.666667                        NaN
# 8978          66.0                  0.513661                        NaN
# 11062         17.0                  0.532258                        NaN
# 13080         42.0                  0.545455                   0.454545
# 13131         23.0                  0.790698                   0.489362
# 13214         66.0                  0.573248                   0.451852
# 13149         33.0                  0.500000                   0.366197
# 13229         42.0                  0.568182                   0.164179
# 13717         25.0                  0.602941                   0.416667
# 13725         24.0                  0.610169                   0.466667
# 13729         45.0                  0.529412                   0.303030
# 14549         29.0                  0.535211                   0.333333
# 14966         47.0                  0.545455                   0.330357
# 15400         19.0                  0.379310                   0.340000
# 15524         17.0                  0.390625                   0.333333
# 15643         29.0                  0.456522                   0.323529
# 16038         27.0                  0.530120                   0.412371
# 16571         59.0                  0.657407                   0.433071
#
#        F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage
# 3121                               0.452381                      0.404762
# 3173                               0.212121                      0.272727
# 8917                               0.250000                      0.464286
# 8978                               0.075758                      0.166667
# 11062                              0.058824                      0.411765
# 13080                              0.261905                      0.357143
# 13131                              0.260870                      0.521739
# 13214                              0.257576                      0.348485
# 13149                              0.121212                      0.303030
# 13229                              0.000000                      0.238095
# 13717                              0.240000                      0.480000
# 13725                              0.208333                      0.500000
# 13729                              0.044444                      0.355556
# 14549                              0.206897                      0.275862
# 14966                              0.148936                      0.319149
# 15400                              0.105263                      0.210526
# 15524                              0.117647                      0.294118
# 15643                              0.068966                      0.344828
# 16038                              0.518519                      0.481481
# 16571                              0.305085                      0.406780

# %%
example_true = df_match_long.loc[df_match_long.Player == 'Adam Pavlasek']

# %%
example_calculated = df_result_long.loc[df_result_long.Player == 'Adam Pavlasek']

# %%
example_true
# Out:
#               Player                  Tournament Tournament_Date  \
# 8917   Adam Pavlasek  Australian Open, Melbourne      2015-01-19
# 8978   Adam Pavlasek  Australian Open, Melbourne      2015-01-19
# 11062  Adam Pavlasek         U.S. Open, New York      2015-08-31
# 13080  Adam Pavlasek          French Open, Paris      2016-05-23
# 13131  Adam Pavlasek          French Open, Paris      2016-05-23
# 13214  Adam Pavlasek          French Open, Paris      2016-05-23
# 13149  Adam Pavlasek          French Open, Paris      2016-05-23
# 13229  Adam Pavlasek          French Open, Paris      2016-05-23
# 13717  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 13725  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 13729  Adam Pavlasek                   Kitzbuhel      2016-07-18
# 14549  Adam Pavlasek                   Stockholm      2016-10-17
# 14966  Adam Pavlasek  Australian Open, Melbourne      2017-01-16
# 15400  Adam Pavlasek                       Dubai      2017-02-27
# 15524  Adam Pavlasek                       Miami      2017-03-20
# 15643  Adam Pavlasek                     Houston      2017-04-10
# 16038  Adam Pavlasek          French Open, Paris      2017-05-29
# 16571  Adam Pavlasek           Wimbledon, London      2017-07-03
# 16618  Adam Pavlasek           Wimbledon, London      2017-07-03
# 17904  Adam Pavlasek  Australian Open, Melbourne      2018-01-15
# 19109  Adam Pavlasek          French Open, Paris      2018-05-28
# 19176  Adam Pavlasek          French Open, Paris      2018-05-28
# 19198  Adam Pavlasek          French Open, Paris      2018-05-28
# 19249  Adam Pavlasek          French Open, Paris      2018-05-28
# 19276  Adam Pavlasek          French Open, Paris      2018-05-28
# 19524  Adam Pavlasek           Wimbledon, London      2018-07-02
# 19570  Adam Pavlasek           Wimbledon, London      2018-07-02
# 20164  Adam Pavlasek         U.S. Open, New York      2018-08-27
#
#       Court_Surface Round_Description   Rank  Retirement_Ind  Sets_Won  \
# 8917           Hard        Qualifying  240.0               0       2.0
# 8978           Hard        Qualifying  240.0               0       1.0
# 11062          Hard        Qualifying  149.0               0       0.0
# 13080          Clay        Qualifying  132.0               0       2.0
# 13131          Clay        Qualifying  132.0               0       2.0
# 13214          Clay       First Round  132.0               0       3.0
# 13149          Clay        Qualifying  132.0               0       1.0
# 13229          Clay      Second Round  132.0               0       0.0
# 13717          Clay       First Round  116.0               0       2.0
# 13725          Clay      Second Round  116.0               0       2.0
# 13729          Clay    Quarter-finals  116.0               0       1.0
# 14549   Indoor Hard       First Round   89.0               0       0.0
# 14966          Hard       First Round   86.0               0       1.0
# 15400          Hard       First Round   93.0               0       0.0
# 15524          Hard       First Round   96.0               0       0.0
# 15643          Clay       First Round   98.0               0       1.0
# 16038          Clay        Qualifying   97.0               0       1.0
# 16571         Grass       First Round  136.0               0       3.0
# 16618         Grass      Second Round  136.0               0       0.0
# 17904          Hard        Qualifying  208.0               0       1.0
# 19109          Clay        Qualifying  185.0               1       1.0
# 19176          Clay        Qualifying  185.0               0       2.0
# 19198          Clay        Qualifying  185.0               0       2.0
# 19249          Clay       First Round  185.0               0       3.0
# 19276          Clay      Second Round  185.0               0       0.0
# 19524         Grass        Qualifying  145.0               0       2.0
# 19570         Grass        Qualifying  145.0               0       1.0
# 20164          Hard        Qualifying  210.0               0       1.0
#
#        Games_Won  Aces  DoubleFaults  FirstServes_Won  FirstServes_In  \
# 8917          13   5.0           1.0             28.0            37.0
# 8978          11  18.0          10.0             66.0            95.0
# 11062          7   2.0           1.0             17.0            31.0
# 13080         15   9.0           3.0             42.0            66.0
# 13131         12   3.0           0.0             23.0            27.0
# 13214         23   7.0           2.0             66.0           102.0
# 13149         10   2.0           2.0             33.0            51.0
# 13229         10   5.0           4.0             42.0            55.0
# 13717         12   3.0           4.0             25.0            30.0
# 13725         12   6.0           2.0             24.0            32.0
# 13729         16   9.0           5.0             45.0            66.0
# 14549          8   6.0           3.0             29.0            42.0
# 14966         15  13.0           3.0             47.0            66.0
# 15400          4   5.0           3.0             19.0            33.0
# 15524          5   3.0           3.0             17.0            31.0
# 15643         10   5.0           5.0             29.0            47.0
# 16038         13   5.0           4.0             27.0            40.0
# 16571         24  14.0           5.0             59.0            70.0
# 16618          5   5.0           4.0             26.0            45.0
# 17904         15  12.0           1.0             44.0            67.0
# 19109          6   0.0           1.0              9.0            17.0
# 19176         12   5.0           0.0             25.0            32.0
# 19198         13   7.0           2.0             42.0            60.0
# 19249         25  16.0           3.0             66.0            88.0
# 19276          5   2.0           0.0             25.0            42.0
# 19524         12   6.0           1.0             32.0            34.0
# 19570         10  10.0           1.0             54.0            74.0
# 20164         10   2.0           4.0             25.0            39.0
#
#        SecondServes_Won  SecondServes_In  BreakPoints_Won  BreakPoints  \
# 8917               15.0             25.0              3.0          7.0
# 8978               38.0             78.0              2.0          5.0
# 11062              17.0             30.0              1.0          1.0
# 13080              15.0             30.0              5.0         11.0
# 13131              11.0             16.0              4.0          6.0
# 13214              26.0             53.0              8.0         17.0
# 13149              11.0             31.0              2.0          4.0
# 13229              12.0             29.0              0.0          0.0
# 13717              20.0             34.0              2.0          6.0
# 13725              14.0             25.0              4.0          5.0
# 13729              23.0             48.0              2.0          2.0
# 14549              12.0             26.0              1.0          6.0
# 14966              16.0             41.0              2.0          7.0
# 15400               6.0             22.0              1.0          2.0
# 15524              11.0             30.0              2.0          2.0
# 15643              18.0             40.0              2.0          2.0
# 16038              21.0             39.0              4.0         14.0
# 16571              17.0             33.0              8.0         18.0
# 16618              15.0             39.0              0.0          1.0
# 17904              16.0             33.0              3.0          4.0
# 19109               7.0             17.0              4.0          5.0
# 19176               5.0             14.0              6.0         13.0
# 19198              14.0             25.0              2.0          8.0
# 19249              23.0             34.0              5.0         10.0
# 19276               7.0             28.0              0.0          1.0
# 19524               9.0             14.0              2.0          3.0
# 19570              23.0             42.0              2.0          7.0
# 20164              17.0             35.0              2.0          7.0
#
#        ReturnPoints_Won  ReturnPoints_Faced  TotalPoints_Won  won  \
# 8917                NaN                 NaN               71   20
# 8978                NaN                 NaN              147   27
# 11062               NaN                 NaN               52   20
# 13080              40.0                88.0               97   28
# 13131              23.0                47.0               57   16
# 13214              61.0               135.0              153   41
# 13149              26.0                71.0               70   25
# 13229              11.0                67.0               65   28
# 13717              25.0                60.0               70   19
# 13725              21.0                45.0               59   18
# 13729              30.0                99.0               98   34
# 14549              24.0                72.0               65   21
# 14966              37.0               112.0              100   37
# 15400              17.0                50.0               42   16
# 15524              15.0                45.0               43   17
# 15643              22.0                68.0               69   27
# 16038              40.0                97.0               88   27
# 16571              55.0               127.0              131   36
# 16618              13.0                60.0               54   23
# 17904              19.0                87.0               89   31
# 19109              18.0                26.0               34    9
# 19176              31.0                56.0               61   16
# 19198              31.0                81.0               87   23
# 19249              50.0               129.0              139   41
# 19276              16.0                67.0               48   23
# 19524              20.0                55.0               61   19
# 19570              44.0               132.0              121   21
# 20164              27.0                77.0               69   24
#
#        Total_Games  F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 8917          28.0                  0.666667                        NaN
# 8978          66.0                  0.513661                        NaN
# 11062         17.0                  0.532258                        NaN
# 13080         42.0                  0.545455                   0.454545
# 13131         23.0                  0.790698                   0.489362
# 13214         66.0                  0.573248                   0.451852
# 13149         33.0                  0.500000                   0.366197
# 13229         42.0                  0.568182                   0.164179
# 13717         25.0                  0.602941                   0.416667
# 13725         24.0                  0.610169                   0.466667
# 13729         45.0                  0.529412                   0.303030
# 14549         29.0                  0.535211                   0.333333
# 14966         47.0                  0.545455                   0.330357
# 15400         19.0                  0.379310                   0.340000
# 15524         17.0                  0.390625                   0.333333
# 15643         29.0                  0.456522                   0.323529
# 16038         27.0                  0.530120                   0.412371
# 16571         59.0                  0.657407                   0.433071
# 16618         26.0                  0.420455                   0.216667
# 17904         44.0                  0.584158                   0.218391
# 19109          9.0                  0.428571                   0.692308
# 19176         25.0                  0.652174                   0.553571
# 19198         42.0                  0.620690                   0.382716
# 19249         66.0                  0.688000                   0.387597
# 19276         25.0                  0.457143                   0.238806
# 19524         32.0                  0.816327                   0.363636
# 19570         54.0                  0.649573                   0.333333
# 20164         25.0                  0.487179                   0.350649
#
#        F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage
# 8917                               0.250000                      0.464286
# 8978                               0.075758                      0.166667
# 11062                              0.058824                      0.411765
# 13080                              0.261905                      0.357143
# 13131                              0.260870                      0.521739
# 13214                              0.257576                      0.348485
# 13149                              0.121212                      0.303030
# 13229                              0.000000                      0.238095
# 13717                              0.240000                      0.480000
# 13725                              0.208333                      0.500000
# 13729                              0.044444                      0.355556
# 14549                              0.206897                      0.275862
# 14966                              0.148936                      0.319149
# 15400                              0.105263                      0.210526
# 15524                              0.117647                      0.294118
# 15643                              0.068966                      0.344828
# 16038                              0.518519                      0.481481
# 16571                              0.305085                      0.406780
# 16618                              0.038462                      0.192308
# 17904                              0.090909                      0.340909
# 19109                              0.555556                      0.666667
# 19176                              0.520000                      0.480000
# 19198                              0.190476                      0.309524
# 19249                              0.151515                      0.378788
# 19276                              0.040000                      0.200000
# 19524                              0.093750                      0.375000
# 19570                              0.129630                      0.185185
# 20164                              0.280000                      0.400000

# %%
example_calculated
# Out:
#            Player        Rank  Retirement_Ind  Sets_Won  Games_Won      Aces  \
# 4   Adam Pavlasek  209.666667             0.0  1.000000  10.333333  8.333333
# 13  Adam Pavlasek  143.833333             0.0  1.333333  12.416667  6.250000
# 20  Adam Pavlasek  129.894737             0.0  1.157895  11.842105  6.578947
#
#     DoubleFaults  FirstServes_Won  FirstServes_In  SecondServes_Won  \
# 4       4.000000        37.000000       54.333333         23.333333
# 13      3.083333        36.666667       52.833333         17.833333
# 20      3.368421        34.947368       50.842105         16.736842
#
#     SecondServes_In  BreakPoints_Won  BreakPoints  ReturnPoints_Won  \
# 4         44.333333         2.000000     4.333333               NaN
# 13        35.416667         2.833333     5.833333             29.00
# 20        35.210526         2.789474     6.105263             28.75
#
#     ReturnPoints_Faced  TotalPoints_Won        won  F_Player_Serve_Win_Ratio  \
# 4                  NaN        90.000000  22.333333                  0.570862
# 13             76.0000        83.666667  24.750000                  0.580659
# 20             77.6875        80.578947  25.263158                  0.544621
#
#     F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 4                         NaN                              0.128194
# 13                   0.382870                              0.165485
# 20                   0.364698                              0.173089
#
#     F_Player_Game_Win_Percentage tournament_date_index
# 4                       0.347572            2016-01-18
# 13                      0.368552            2017-01-16
# 20                      0.351148            2018-01-15

# %%
example_true.loc[example_true.Tournament_Date<'2018-01-15','Rank'].mean()
# Out:
# 129.89473684210526

# %%
example_true.shape
# Out:
# (28, 26)

# %%
example_true.loc[example_true.Tournament_Date<'2016-01-18','Rank'].mean()
# Out:
# 209.66666666666666

# %%
df_result_long.tail()
# Out:
#                  Player        Rank  Retirement_Ind  Sets_Won  Games_Won  \
# 35761  Yusuke Takahashi  262.000000             0.0      1.00  14.000000
# 35762   Zbynek Mlynarik  238.000000             0.0      1.00  12.000000
# 35796          Ze Zhang  208.200000             0.0      0.75   9.850000
# 35802            Zhe Li  258.666667             0.0      0.50   6.666667
# 35807     Zhizhen Zhang  530.200000             0.0      1.40  11.600000
#
#        Aces  DoubleFaults  FirstServes_Won  FirstServes_In  SecondServes_Won  \
# 35761  4.00      2.000000             28.0           43.00         22.000000
# 35762  9.00      4.000000             32.0           46.00         20.000000
# 35796  3.85      3.800000             29.8           46.95         11.850000
# 35802  2.50      0.833333             23.0           37.50          9.166667
# 35807  5.80      2.600000             30.6           42.80         15.800000
#
#        SecondServes_In  BreakPoints_Won  BreakPoints  ReturnPoints_Won  \
# 35761        44.000000         4.000000    10.000000         36.000000
# 35762        50.000000         3.000000     7.000000         28.000000
# 35796        26.100000         2.350000     5.850000         23.529412
# 35802        21.333333         1.166667     3.666667         17.500000
# 35807        32.800000         2.400000     6.000000         26.600000
#
#        ReturnPoints_Faced  TotalPoints_Won    won  F_Player_Serve_Win_Ratio  \
# 35761           90.000000        86.000000  30.00                  0.539326
# 35762           80.000000        80.000000  28.00                  0.480000
# 35796           66.823529        67.450000  22.85                  0.490419
# 35802           54.833333        49.666667  18.50                  0.503743
# 35807           71.600000        73.000000  22.60                  0.552725
#
#        F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 35761                   0.400000                              0.357143
# 35762                   0.350000                              0.218750
# 35796                   0.346640                              0.190623
# 35802                   0.302598                              0.150431
# 35807                   0.366874                              0.223653
#
#        F_Player_Game_Win_Percentage tournament_date_index
# 35761                      0.500000            2018-01-15
# 35762                      0.375000            2018-01-15
# 35796                      0.321596            2018-01-15
# 35802                      0.277606            2018-01-15
# 35807                      0.393075            2018-01-15

# %%
# Randomise the match_wide dataset so the first player is not always the winner

# set a seed so the random number is reproducable
np.random.seed(2)

# randomise a number 0/1 with 50% chance each
# if 0 then take the winner, 1 then take loser

df_match_wide['random_number'] = np.random.randint(2, size=len(df_match_wide))

df_match_wide['randomised_player'] = np.where(df_match_wide['random_number']==0,df_match_wide['Winner'],df_match_wide['Loser'])

# set the target (win/loss) based on the new randomise number

df_match_wide['target'] = np.where(df_match_wide['random_number']==0,1,0)

# %%
df_match_wide.tail()
# Out:
#                         Winner                    Loser Tournament  \
# 20802          Karen Khachanov           Novak Djokovic      Paris
# 20803  Jaume Antoni Munar Clar           Frances Tiafoe      Milan
# 20804           Frances Tiafoe           Hubert Hurkacz      Milan
# 20805           Hubert Hurkacz  Jaume Antoni Munar Clar      Milan
# 20806            Andrey Rublev             Liam Caruana      Milan
#
#       Tournament_Date Court_Surface Round_Description Winner_Rank Loser_Rank  \
# 20802      2018-10-29   Indoor Hard            Finals          18          2
# 20803      2018-11-05   Indoor Hard               NaN          76         40
# 20804      2018-11-05   Indoor Hard               NaN          40         85
# 20805      2018-11-05   Indoor Hard               NaN          85         76
# 20806      2018-11-05   Indoor Hard               NaN          68          .
#
#        Retirement_Ind Winner_Sets_Won  Winner_Games_Won Winner_Aces  \
# 20802               0               2                13           9
# 20803               0               3                12           7
# 20804               0               3                14          11
# 20805               0               3                17           5
# 20806               0               3                12           9
#
#       Winner_DoubleFaults Winner_FirstServes_Won Winner_FirstServes_In  \
# 20802                   2                     38                    50
# 20803                   1                     25                    27
# 20804                   1                     39                    53
# 20805                   3                     38                    53
# 20806                   2                     33                    39
#
#       Winner_SecondServes_Won Winner_SecondServes_In Winner_BreakPoints_Won  \
# 20802                       8                     16                      3
# 20803                      16                     19                      2
# 20804                      17                     25                      2
# 20805                      13                     27                      6
# 20806                       6                     18                      3
#
#       Winner_BreakPoints Winner_ReturnPoints_Won Winner_ReturnPoints_Faced  \
# 20802                  8                      27                        71
# 20803                  4                      19                        46
# 20804                  7                      22                        67
# 20805                 12                      40                        98
# 20806                  5                      21                        53
#
#        Winner_TotalPoints_Won Loser_Sets_Won  Loser_Games_Won Loser_Aces  \
# 20802                      73              0                9          5
# 20803                      60              0                5          6
# 20804                      78              1               10          9
# 20805                      91              2               13          8
# 20806                      60              0                6          6
#
#       Loser_DoubleFaults Loser_FirstServes_Won Loser_FirstServes_In  \
# 20802                  1                    30                   43
# 20803                  3                    21                   29
# 20804                  4                    35                   48
# 20805                  1                    43                   63
# 20806                  1                    28                   39
#
#       Loser_SecondServes_Won Loser_SecondServes_In Loser_BreakPoints_Won  \
# 20802                     14                    28                     1
# 20803                      6                    17                     0
# 20804                     10                    19                     1
# 20805                     15                    35                     3
# 20806                      4                    14                     1
#
#       Loser_BreakPoints Loser_ReturnPoints_Won Loser_ReturnPoints_Faced  \
# 20802                 5                     20                       66
# 20803                 2                      5                       46
# 20804                 7                     22                       78
# 20805                 9                     29                       80
# 20806                 3                     18                       57
#
#        Loser_TotalPoints_Won  Total_Games  random_number  \
# 20802                     64           22              0
# 20803                     32           17              0
# 20804                     67           24              1
# 20805                     87           30              0
# 20806                     50           18              1
#
#              randomised_player  target
# 20802          Karen Khachanov       1
# 20803  Jaume Antoni Munar Clar       1
# 20804           Hubert Hurkacz       0
# 20805           Hubert Hurkacz       1
# 20806             Liam Caruana       0

# %%
df_match_wide['random_number'].mean()
# Out:
# 0.5032441005430864

# %%
df_match_wide['target'].mean()
# Out:
# 0.49675589945691356

# %%
df_match_wide_aus_open = df_match_wide.loc[df_match_wide.Tournament=='Australian Open, Melbourne', \
                                           ['Winner','Loser','Tournament','Tournament_Date',
                                           'target','randomised_player','random_number']]

# Get the rolling features

df_match_wide_aus_open_features = df_match_wide_aus_open.merge(df_result_long, how='left',
                         left_on = ['randomised_player','Tournament_Date'],
                         right_on = ['Player','tournament_date_index'],validate ='m:1')

# %%
df_match_wide_aus_open_features.loc[df_match_wide_aus_open_features.Player.isna()].shape
# Out:
# (196, 29)

# %%
df_match_wide_aus_open_features.loc[df_match_wide_aus_open_features.Player.isna(),'Tournament_Date'].value_counts()
# Out:
# 2012-01-16    128
# 2014-01-13     22
# 2013-01-14     19
# 2018-01-15     10
# 2015-01-19      7
# 2017-01-16      5
# 2016-01-18      5
# Name: Tournament_Date, dtype: int64

# %%
df_match_wide_aus_open_features.loc[
    (df_match_wide_aus_open_features.Player.isna())
    & (df_match_wide_aus_open_features.Tournament_Date=='2018-01-15')
].head()
# Out:
#                      Winner            Loser                  Tournament  \
# 1436          Stefan Kozlov      Blake Ellis  Australian Open, Melbourne
# 1441                  Di Wu      Dayne Kelly  Australian Open, Melbourne
# 1444           Bjorn Propst   Facundo Bagnis  Australian Open, Melbourne
# 1453        Carlos Taberner    Joao Monteiro  Australian Open, Melbourne
# 1462  Karim-Mohamed Maamoun  Marcelo Arevalo  Australian Open, Melbourne
#
#      Tournament_Date  target      randomised_player  random_number Player  \
# 1436      2018-01-15       0            Blake Ellis              1    NaN
# 1441      2018-01-15       0            Dayne Kelly              1    NaN
# 1444      2018-01-15       1           Bjorn Propst              0    NaN
# 1453      2018-01-15       1        Carlos Taberner              0    NaN
# 1462      2018-01-15       1  Karim-Mohamed Maamoun              0    NaN
#
#       Rank  Retirement_Ind  Sets_Won  Games_Won  Aces  DoubleFaults  \
# 1436   NaN             NaN       NaN        NaN   NaN           NaN
# 1441   NaN             NaN       NaN        NaN   NaN           NaN
# 1444   NaN             NaN       NaN        NaN   NaN           NaN
# 1453   NaN             NaN       NaN        NaN   NaN           NaN
# 1462   NaN             NaN       NaN        NaN   NaN           NaN
#
#       FirstServes_Won  FirstServes_In  SecondServes_Won  SecondServes_In  \
# 1436              NaN             NaN               NaN              NaN
# 1441              NaN             NaN               NaN              NaN
# 1444              NaN             NaN               NaN              NaN
# 1453              NaN             NaN               NaN              NaN
# 1462              NaN             NaN               NaN              NaN
#
#       BreakPoints_Won  BreakPoints  ReturnPoints_Won  ReturnPoints_Faced  \
# 1436              NaN          NaN               NaN                 NaN
# 1441              NaN          NaN               NaN                 NaN
# 1444              NaN          NaN               NaN                 NaN
# 1453              NaN          NaN               NaN                 NaN
# 1462              NaN          NaN               NaN                 NaN
#
#       TotalPoints_Won  won  F_Player_Serve_Win_Ratio  \
# 1436              NaN  NaN                       NaN
# 1441              NaN  NaN                       NaN
# 1444              NaN  NaN                       NaN
# 1453              NaN  NaN                       NaN
# 1462              NaN  NaN                       NaN
#
#       F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 1436                        NaN                                   NaN
# 1441                        NaN                                   NaN
# 1444                        NaN                                   NaN
# 1453                        NaN                                   NaN
# 1462                        NaN                                   NaN
#
#       F_Player_Game_Win_Percentage tournament_date_index
# 1436                           NaN                   NaT
# 1441                           NaN                   NaT
# 1444                           NaN                   NaT
# 1453                           NaN                   NaT
# 1462                           NaN                   NaT

# %%
df_match_long.loc[df_match_long.Player=='Dayne Kelly']
# Out:
#             Player                  Tournament Tournament_Date Court_Surface  \
# 17915  Dayne Kelly  Australian Open, Melbourne      2018-01-15          Hard
#
#       Round_Description   Rank  Retirement_Ind  Sets_Won  Games_Won  Aces  \
# 17915        Qualifying  274.0               0       0.0          7   1.0
#
#        DoubleFaults  FirstServes_Won  FirstServes_In  SecondServes_Won  \
# 17915           5.0             23.0            41.0              12.0
#
#        SecondServes_In  BreakPoints_Won  BreakPoints  ReturnPoints_Won  \
# 17915             31.0              2.0          4.0              24.0
#
#        ReturnPoints_Faced  TotalPoints_Won  won  Total_Games  \
# 17915                66.0               59   20         23.0
#
#        F_Player_Serve_Win_Ratio  F_Player_Return_Win_Ratio  \
# 17915                   0.38961                   0.363636
#
#        F_Player_BreakPoints_Per_Return_Game  F_Player_Game_Win_Percentage
# 17915                              0.173913                      0.304348

# %%
df_result_long.loc[df_result_long.Player=='Dayne Kelly']
# Out:
# Empty DataFrame
# Columns: [Player, Rank, Retirement_Ind, Sets_Won, Games_Won, Aces, DoubleFaults, FirstServes_Won, FirstServes_In, SecondServes_Won, SecondServes_In, BreakPoints_Won, BreakPoints, ReturnPoints_Won, ReturnPoints_Faced, TotalPoints_Won, won, F_Player_Serve_Win_Ratio, F_Player_Return_Win_Ratio, F_Player_BreakPoints_Per_Return_Game, F_Player_Game_Win_Percentage, tournament_date_index]
# Index: []

# %%
df_match_wide_aus_open_features.tail()
# Out:
#              Winner            Loser                  Tournament  \
# 1660    Hyeon Chung  Tennys Sandgren  Australian Open, Melbourne
# 1661  Roger Federer    Tomas Berdych  Australian Open, Melbourne
# 1662  Roger Federer      Hyeon Chung  Australian Open, Melbourne
# 1663    Marin Cilic      Kyle Edmund  Australian Open, Melbourne
# 1664  Roger Federer      Marin Cilic  Australian Open, Melbourne
#
#      Tournament_Date  target randomised_player  random_number         Player  \
# 1660      2018-01-15       1       Hyeon Chung              0    Hyeon Chung
# 1661      2018-01-15       1     Roger Federer              0  Roger Federer
# 1662      2018-01-15       0       Hyeon Chung              1    Hyeon Chung
# 1663      2018-01-15       1       Marin Cilic              0    Marin Cilic
# 1664      2018-01-15       0       Marin Cilic              1    Marin Cilic
#
#        Rank  Retirement_Ind  Sets_Won  Games_Won   Aces  DoubleFaults  \
# 1660  55.40            0.05      1.45       12.0   4.20           3.3
# 1661   2.40            0.00      2.00       15.4   8.95           2.0
# 1662  55.40            0.05      1.45       12.0   4.20           3.3
# 1663   5.05            0.05      1.45       12.5  10.00           2.8
# 1664   5.05            0.05      1.45       12.5  10.00           2.8
#
#       FirstServes_Won  FirstServes_In  SecondServes_Won  SecondServes_In  \
# 1660            32.60           46.25             13.80            28.05
# 1661            35.30           44.40             17.65            29.65
# 1662            32.60           46.25             13.80            28.05
# 1663            32.85           42.00             14.25            29.55
# 1664            32.85           42.00             14.25            29.55
#
#       BreakPoints_Won  BreakPoints  ReturnPoints_Won  ReturnPoints_Faced  \
# 1660             2.65         6.50             28.60               74.25
# 1661             3.55         8.85             35.35               88.30
# 1662             2.65         6.50             28.60               74.25
# 1663             2.90         6.45             27.90               71.65
# 1664             2.90         6.45             27.90               71.65
#
#       TotalPoints_Won   won  F_Player_Serve_Win_Ratio  \
# 1660             75.0  23.2                  0.552529
# 1661             88.3  26.4                  0.684348
# 1662             75.0  23.2                  0.552529
# 1663             75.0  23.2                  0.635077
# 1664             75.0  23.2                  0.635077
#
#       F_Player_Return_Win_Ratio  F_Player_BreakPoints_Per_Return_Game  \
# 1660                   0.385395                              0.214333
# 1661                   0.402656                              0.268957
# 1662                   0.385395                              0.214333
# 1663                   0.393866                              0.205465
# 1664                   0.393866                              0.205465
#
#       F_Player_Game_Win_Percentage tournament_date_index
# 1660                      0.375871            2018-01-15
# 1661                      0.449503            2018-01-15
# 1662                      0.375871            2018-01-15
# 1663                      0.401909            2018-01-15
# 1664                      0.401909            2018-01-15
